# %%
import csv
import bmt
import requests
import linkml
from linkml_runtime import SchemaView
from collections import defaultdict
from typing import Tuple, List
import requests
import yaml
from pprint import pprint
from biothings_explorer.smartapi_kg.dataload import load_specs
import pandas

tk = bmt.Toolkit('https://raw.githubusercontent.com/biolink/biolink-model/2.2.12/biolink-model.yaml')
tsv_file = open("predicates.tsv", "w")
tsv_attributes = open("attributes.tsv", "w")
tsv_writer = csv.writer(tsv_file, delimiter='\t')
tsv_writer_att = csv.writer(tsv_attributes, delimiter='\t')

# %%
def sample_predicates():
    specs = load_specs()
    kp_titles = []
    for spec in specs:
        if 'x-translator' not in spec['info']:
            continue
        if spec['info']['x-translator']['component'] == 'KP':
            kp_titles.append(spec['info']['title'])
        if 'servers' not in spec:
            continue
        else:
            url = spec['servers'][0]['url']
            apititle = '_'.join(spec['info']['title'].split())
            if url.endswith('/'):
                url = url[:-1]
            predicates_url = f'{url}/meta_knowledge_graph'
            print(predicates_url)
            trapi, predicates = get_predicates(predicates_url)
            # if is_trapi:
            if not predicates:
                continue
            else:
                print("got predicates")
                preds, attribs, url = dump_trapi_predicate_results(predicates, predicates_url)
                predicates = set(preds)
                attributes = set(attribs)
                for pred in predicates:
                    tsv_writer.writerow([apititle, url, pred])
                for attrib in attributes:
                    tsv_writer_att.writerow([apititle, url, attrib])
            # else:
            #     dump_smartapi_predicate_results(spec['info']['title'])

# %%
def in_biolink_model(predicate):
    is_predicate = tk.is_predicate(predicate)
    return is_predicate

# %%
def dump_trapi_predicate_results(predicates, url):
    preds = []
    attribs = []
    for edge in predicates.get('edges'):
        predicate = edge.get('predicate')
        subject = edge.get('subject')
        tobject = edge.get('object')
        if 'attributes' in edge and edge.get('attributes') is not None:
            for attribute in edge.get('attributes'):
                attribs.append(attribute.get('attribute_type_id'))
        preds.append(predicate)
    return preds, attribs, url

            # tsv_writer.writerow([subject, predicate, tobject, url])

# %%
def get_predicates(pr_url):
    try:
        response = requests.get(pr_url)
        if response.status_code == 200:
            return True, response.json()
        else:
            return False, {}
    except:
        return False, {}

# %%
if __name__ == '__main__':
    sample_predicates()
# Out:
# /socio_environmental_exposures_api/v1/meta_knowledge_graph
# /cmaq_exposures_api/v1/meta_knowledge_graph
# /roadway_proximity_api/v1/meta_knowledge_graph
# https://name-resolution-sri.renci.org/meta_knowledge_graph
# https://icees-pcd.renci.org/meta_knowledge_graph
# got predicates
# https://icees-dili-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/proteins/api/meta_knowledge_graph
# https://icees-asthma-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://icees-asthma.renci.org/meta_knowledge_graph
# got predicates
# https://translator-workflow-runner.renci.org/meta_knowledge_graph
# https://icees-pcd-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/ols/api/meta_knowledge_graph
# https://www.ncbi.nlm.nih.gov/research/bionlp/litvar/api/v1/meta_knowledge_graph
# https://icees-dili.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/QuickGO/services/meta_knowledge_graph
# https://ontology-kp.apps.renci.org/meta_knowledge_graph
# got predicates
# https://trapi.monarchinitiative.org/1.2/meta_knowledge_graph
# https://medikanren-trapi.ci.transltr.io/v2/meta_knowledge_graph
# https://automat.renci.org/gtex/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/intact/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/gtopdb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/drugcentral/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/chemical-normalization/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/ctd/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/cord19/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/panther/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/textminingkp/1.2/meta_knowledge_graph
# got predicates
# https://bl-lookup-sri.renci.org/meta_knowledge_graph
# https://automat.renci.org/hmdb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/covidkopkg/1.2/meta_knowledge_graph
# got predicates
# https://nodenormalization-sri.renci.org/1.2/meta_knowledge_graph
# https://nodenormalization-dev.apps.renci.org/1.2/meta_knowledge_graph
# https://automat.renci.org/pharos/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/human-goa/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/uberongraph/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/biolink/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/viral-proteome/1.2/meta_knowledge_graph
# got predicates
# https://cam-kp-api.renci.org/1.2.0/meta_knowledge_graph
# got predicates
# https://automat.renci.org/hgnc/1.2/meta_knowledge_graph
# got predicates
# https://cam-kp-api.renci.org/1.2.0/meta_knowledge_graph
# got predicates
# https://automat.renci.org/robokopkg/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/ontological-hierarchy/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/foodb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/gwas-catalog/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/molepro-fda/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/hetio/1.2/meta_knowledge_graph
# got predicates
# https://explanatory-agent.azurewebsites.net/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/uberon/meta_knowledge_graph
# https://aragorn-dev.apps.renci.org/1.2/meta_knowledge_graph
# http://chp.thayer.dartmouth.edu/meta_knowledge_graph
# got predicates
# https://smart-api.info/api/meta_knowledge_graph
# https://biothings.ncats.io/hpo/meta_knowledge_graph
# https://aragorn.renci.org/1.2/meta_knowledge_graph
# https://cooccurrence-p36smkc6hq-uc.a.run.app/meta_knowledge_graph
# got predicates
# https://spokekp.healthdatascience.cloud/api/v1.2/meta_knowledge_graph
# got predicates
# https://cohd.io/api/meta_knowledge_graph
# got predicates
# https://openpredict.semanticscience.org/meta_knowledge_graph
# got predicates
# https://mygene.info/v3/meta_knowledge_graph
# https://myvariant.info/v1/meta_knowledge_graph
# https://biothings.ncats.io/rhea/meta_knowledge_graph
# https://molepro-trapi.transltr.io/molepro/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://ia.healthdatascience.cloud/api/v1.2/meta_knowledge_graph
# got predicates
# http://mydisease.info/v1/meta_knowledge_graph
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/DISEASES/meta_knowledge_graph
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/mgigene2phenotype/meta_knowledge_graph
# https://mychem.info/v1/meta_knowledge_graph
# https://biothings.ncats.io/ebigene2phenotype/meta_knowledge_graph
# https://biothings.ncats.io/go_bp/meta_knowledge_graph
# https://arax.ncats.io/beta/api/rtxkg2/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/go_cc/meta_knowledge_graph
# https://arax.ncats.io/api/rtxkg2/v1.2/meta_knowledge_graph
# got predicates
# https://api.bte.ncats.io/v1/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/idisk/meta_knowledge_graph
# https://biothings.ncats.io/go_mf/meta_knowledge_graph
# https://api.bte.ncats.io/v1/team/Service%20Provider/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/multiomics_wellness_kp/meta_knowledge_graph
# https://api.collaboratory.semanticscience.org/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/dgidb/meta_knowledge_graph
# https://biothings.ncats.io/semmeddb/meta_knowledge_graph
# https://biothings.ncats.io/drug_response_kp/meta_knowledge_graph
# https://api.monarchinitiative.org/api/meta_knowledge_graph
# https://biothings.ncats.io/text_mining_targeted_association/meta_knowledge_graph
# https://arax.ncats.io/api/arax/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/clinical_risk_kp/meta_knowledge_graph
# https://arax.ncats.io/beta/api/arax/v1.2/meta_knowledge_graph
# got predicates

# %%
sv = SchemaView('https://raw.githubusercontent.com/biolink/biolink-model/master/biolink-model.yaml')

# %%
for s in sv.all_slots().values():
    rows = []
    if 'related to' in sv.slot_ancestors(s.name):
        rows.append(s.name)
        for x in sv.slot_children(s.name):
            rows.append(x)
        
        rows = []
# Out:
# ['related to', 'related to at concept level', 'related to at instance level', 'disease has location', 'composed primarily of']
# ['related to at concept level', 'superclass of', 'subclass of', 'close match', 'broad match', 'narrow match']
# ['related to at instance level', 'associated with', 'opposite of', 'has real world evidence of association with', 'target for', 'has target', 'active in', 'acts upstream of', 'has upstream actor', 'mentions', 'mentioned by', 'contributor', 'has contributor', 'interacts with', 'affects', 'affected by', 'diagnoses', 'is diagnosed by', 'increases amount or activity of', 'decreases amount or activity of', 'gene product of', 'has gene product', 'transcribed to', 'transcribed from', 'translates to', 'translation of', 'coexists with', 'genetic association', 'affects risk for', 'risk affected by', 'contributes to', 'contribution from', 'caused by', 'treated by', 'has phenotype', 'phenotype of', 'occurs in', 'contains process', 'located in', 'location of', 'similar to', 'has sequence location', 'sequence location of', 'model of', 'models', 'overlaps', 'has participant', 'participates in', 'derives into', 'derives from', 'manifestation of', 'has manifestation', 'produces', 'produced by', 'temporally related to', 'related condition', 'is sequence variant of', 'has sequence variant', 'disease has basis in', 'occurs in disease', 'contraindicated for', 'has contraindication', 'has not completed', 'not completed by', 'has completed', 'completed by', 'in linkage disequilibrium with', 'has increased amount', 'increased amount of', 'has decreased amount', 'decreased amount in', 'lacks part', 'missing from', 'develops from', 'develops into', 'in taxon', 'taxon of', 'has molecular consequence', 'is molecular consequence of']
# ['associated with', 'associated with sensitivity to', 'sensitivity associated with', 'associated with resistance to', 'resistance associated with', 'correlated with']
# ['superclass of']
# ['subclass of']
# ['same as']
# ['close match', 'exact match']
# ['exact match', 'same as']
# ['broad match']
# ['narrow match']
# ['opposite of']
# ['has real world evidence of association with']
# ['target for']
# ['has target']
# ['active in']
# ['acts upstream of', 'acts upstream of positive effect', 'acts upstream of negative effect', 'acts upstream of or within', 'acts upstream of or within positive effect', 'acts upstream of or within negative effect']
# ['has upstream actor', 'has positive upstream actor', 'has negative upstream actor', 'has upstream or within actor']
# ['acts upstream of positive effect']
# ['has positive upstream actor']
# ['acts upstream of negative effect']
# ['has negative upstream actor']
# ['acts upstream of or within']
# ['has upstream or within actor', 'has positive upstream or within actor', 'has negative upstream or within actor']
# ['acts upstream of or within positive effect']
# ['has positive upstream or within actor']
# ['acts upstream of or within negative effect']
# ['has negative upstream or within actor']
# ['mentions']
# ['mentioned by']
# ['contributor', 'provider', 'publisher', 'editor', 'author']
# ['has contributor', 'has provider', 'has publisher', 'has editor', 'has author']
# ['provider']
# ['has provider']
# ['publisher']
# ['has publisher']
# ['editor']
# ['has editor']
# ['author']
# ['has author']
# ['interacts with', 'physically interacts with', 'genetically interacts with', 'directly interacts with']
# ['physically interacts with', 'chemically interacts with', 'molecularly interacts with']
# ['chemically interacts with']
# ['molecularly interacts with', 'decreases molecular interaction', 'molecular interaction decreased by', 'increases molecular interaction', 'molecular interaction increased by']
# ['genetically interacts with']
# ['affects', 'affects abundance of', 'affects activity of', 'affects expression of', 'affects folding of', 'affects localization of', 'affects metabolic processing of', 'affects molecular modification of', 'affects synthesis of', 'affects degradation of', 'affects mutation rate of', 'affects response to', 'affects splicing of', 'affects stability of', 'affects transport of', 'affects secretion of', 'affects uptake of', 'process regulates process', 'entity regulates entity', 'disrupts', 'ameliorates', 'exacerbates', 'affects expression in']
# ['affected by', 'abundance affected by', 'activity affected by', 'expression affected by', 'folding affected by', 'localization affected by', 'metabolic processing affected by', 'molecular modification affected by', 'synthesis affected by', 'degradation affected by', 'mutation rate affected by', 'response affected by', 'splicing affected by', 'stability affected by', 'transport affected by', 'secretion affected by', 'uptake affected by', 'process regulated by process', 'entity regulated by entity', 'disrupted by', 'is ameliorated by', 'is exacerbated by']
# ['associated with sensitivity to']
# ['sensitivity associated with']
# ['associated with resistance to']
# ['resistance associated with']
# ['diagnoses']
# ['is diagnosed by']
# ['increases amount or activity of', 'increases abundance of', 'increases activity of', 'increases expression of', 'increases folding of', 'increases localization of', 'increases metabolic processing of', 'increases molecular modification of', 'increases synthesis of', 'decreases degradation of', 'increases mutation rate of', 'increases response to', 'increases splicing of', 'increases stability of', 'increases transport of', 'increases secretion of', 'increases uptake of', 'increases molecular interaction']
# ['decreases amount or activity of', 'decreases abundance of', 'decreases activity of', 'decreases expression of', 'decreases folding of', 'decreases localization of', 'decreases metabolic processing of', 'decreases molecular modification of', 'decreases synthesis of', 'increases degradation of', 'decreases mutation rate of', 'decreases response to', 'decreases splicing of', 'decreases stability of', 'decreases transport of', 'decreases secretion of', 'decreases uptake of', 'decreases molecular interaction']
# ['affects abundance of', 'increases abundance of', 'decreases abundance of']
# ['abundance affected by', 'abundance increased by', 'abundance decreased by']
# ['increases abundance of']
# ['abundance increased by']
# ['decreases abundance of']
# ['abundance decreased by']
# ['increases activity of']
# ['affects activity of', 'increases activity of', 'decreases activity of']
# ['activity affected by', 'activity increased by', 'activity decreased by']
# ['activity increased by']
# ['decreases activity of']
# ['activity decreased by']
# ['affects expression of', 'increases expression of', 'decreases expression of']
# ['expression affected by', 'expression increased by', 'expression decreased by']
# ['increases expression of']
# ['expression increased by']
# ['decreases expression of']
# ['expression decreased by']
# ['affects folding of', 'increases folding of', 'decreases folding of']
# ['folding affected by', 'folding increased by', 'folding decreased by']
# ['increases folding of']
# ['folding increased by']
# ['decreases folding of']
# ['folding decreased by']
# ['affects localization of', 'increases localization of', 'decreases localization of']
# ['localization affected by', 'localization increased by', 'localization decreased by']
# ['increases localization of']
# ['localization increased by']
# ['decreases localization of']
# ['localization decreased by']
# ['affects metabolic processing of', 'increases metabolic processing of', 'decreases metabolic processing of']
# ['metabolic processing affected by', 'metabolic processing increased by', 'metabolic processing decreased by']
# ['increases metabolic processing of']
# ['metabolic processing increased by']
# ['decreases metabolic processing of']
# ['metabolic processing decreased by']
# ['affects molecular modification of', 'increases molecular modification of', 'decreases molecular modification of']
# ['molecular modification affected by', 'molecular modification increased by', 'molecular modification decreased by']
# ['increases molecular modification of']
# ['molecular modification increased by']
# ['decreases molecular modification of']
# ['molecular modification decreased by']
# ['affects synthesis of', 'increases synthesis of', 'decreases synthesis of']
# ['synthesis affected by', 'synthesis increased by', 'synthesis decreased by']
# ['increases synthesis of']
# ['synthesis increased by']
# ['decreases synthesis of']
# ['synthesis decreased by']
# ['affects degradation of', 'increases degradation of', 'decreases degradation of']
# ['degradation affected by', 'degradation increased by', 'degradation decreased by']
# ['increases degradation of']
# ['degradation increased by']
# ['decreases degradation of']
# ['degradation decreased by']
# ['affects mutation rate of', 'increases mutation rate of', 'decreases mutation rate of']
# ['mutation rate affected by', 'mutation rate increased by', 'mutation rate decreased by']
# ['increases mutation rate of']
# ['mutation rate increased by']
# ['decreases mutation rate of']
# ['mutation rate decreased by']
# ['affects response to', 'increases response to', 'decreases response to']
# ['response affected by', 'response increased by', 'response decreased by']
# ['increases response to']
# ['response increased by']
# ['decreases response to']
# ['response decreased by']
# ['affects splicing of', 'increases splicing of', 'decreases splicing of']
# ['splicing affected by', 'splicing increased by', 'splicing decreased by']
# ['increases splicing of']
# ['splicing increased by']
# ['decreases splicing of']
# ['splicing decreased by']
# ['affects stability of', 'increases stability of', 'decreases stability of']
# ['stability affected by', 'stability increased by', 'stability decreased by']
# ['increases stability of']
# ['stability increased by']
# ['decreases stability of']
# ['stability decreased by']
# ['affects transport of', 'increases transport of', 'decreases transport of']
# ['transport affected by', 'transport increased by', 'transport decreased by']
# ['increases transport of']
# ['transport increased by']
# ['decreases transport of']
# ['transport decreased by']
# ['affects secretion of', 'increases secretion of', 'decreases secretion of']
# ['secretion affected by', 'secretion increased by', 'secretion decreased by']
# ['increases secretion of']
# ['secretion increased by']
# ['decreases secretion of']
# ['secretion decreased by']
# ['affects uptake of', 'increases uptake of', 'decreases uptake of']
# ['uptake affected by', 'uptake increased by', 'uptake decreased by']
# ['increases uptake of']
# ['uptake increased by']
# ['decreases uptake of']
# ['uptake decreased by']
# ['process regulates process', 'process positively regulates process', 'process negatively regulates process']
# ['process regulated by process', 'process positively regulated by process', 'process negatively regulated by process']
# ['process positively regulates process']
# ['process positively regulated by process']
# ['process negatively regulates process']
# ['process negatively regulated by process']
# ['entity regulates entity', 'entity positively regulates entity', 'entity negatively regulates entity']
# ['entity regulated by entity', 'entity positively regulated by entity', 'entity negatively regulated by entity']
# ['entity positively regulates entity']
# ['entity positively regulated by entity']
# ['entity negatively regulates entity']
# ['entity negatively regulated by entity']
# ['disrupts']
# ['disrupted by']
# ['gene product of']
# ['has gene product']
# ['transcribed to']
# ['transcribed from']
# ['translates to']
# ['translation of']
# ['homologous to', 'paralogous to', 'orthologous to', 'xenologous to']
# ['paralogous to']
# ['orthologous to']
# ['xenologous to']
# ['coexists with', 'in pathway with', 'in complex with', 'in cell population with', 'colocalizes with']
# ['in pathway with']
# ['in complex with']
# ['in cell population with']
# ['colocalizes with']
# ['genetic association', 'gene associated with condition', 'condition associated with gene']
# ['gene associated with condition']
# ['condition associated with gene']
# ['affects risk for', 'predisposes', 'prevents']
# ['risk affected by', 'prevented by']
# ['predisposes']
# ['contributes to', 'causes']
# ['contribution from']
# ['causes', 'causes adverse event', 'adverse event caused by']
# ['caused by']
# ['ameliorates', 'treats']
# ['is ameliorated by']
# ['exacerbates']
# ['is exacerbated by']
# ['treats', 'approved to treat']
# ['treated by', 'approved for treatment by']
# ['approved to treat']
# ['approved for treatment by']
# ['prevents']
# ['prevented by']
# ['correlated with', 'positively correlated with', 'negatively correlated with', 'occurs together in literature with', 'coexpressed with', 'has biomarker', 'biomarker for']
# ['positively correlated with']
# ['negatively correlated with']
# ['occurs together in literature with']
# ['coexpressed with']
# ['has biomarker']
# ['biomarker for']
# ['expressed in']
# ['expresses']
# ['has phenotype']
# ['phenotype of']
# ['occurs in']
# ['contains process']
# ['located in', 'expressed in']
# ['location of', 'expresses']
# ['disease has location']
# ['similar to', 'homologous to', 'chemically similar to']
# ['chemically similar to']
# ['has sequence location']
# ['sequence location of']
# ['model of']
# ['models']
# ['overlaps', 'has part', 'part of']
# ['has part', 'has plasma membrane part', 'has food component', 'has active ingredient', 'has excipient', 'has variant part']
# ['has plasma membrane part']
# ['composed primarily of']
# ['plasma membrane part of']
# ['part of', 'plasma membrane part of', 'food component of', 'is active ingredient of', 'is excipient of', 'variant part of']
# ['has input', 'consumes']
# ['is input of', 'consumed by']
# ['has output']
# ['is output of']
# ['has participant', 'has input', 'has output', 'has catalyst', 'has substrate', 'actively involves', 'enabled by']
# ['catalyzes']
# ['has catalyst']
# ['has substrate']
# ['is substrate of']
# ['participates in', 'is input of', 'is output of', 'catalyzes', 'is substrate of', 'actively involved in', 'enables']
# ['actively involved in', 'capable of']
# ['actively involves', 'has capability']
# ['capable of']
# ['has capability']
# ['enables']
# ['enabled by']
# ['derives into', 'has metabolite']
# ['derives from', 'is metabolite of']
# ['is metabolite of']
# ['has metabolite']
# ['food component of', 'nutrient of']
# ['has food component', 'has nutrient']
# ['nutrient of']
# ['has nutrient']
# ['is active ingredient of']
# ['has active ingredient']
# ['is excipient of']
# ['has excipient']
# ['manifestation of']
# ['has manifestation']
# ['produces']
# ['produced by']
# ['consumes']
# ['consumed by']
# ['temporally related to', 'precedes', 'preceded by']
# ['precedes']
# ['preceded by']
# ['directly interacts with']
# ['affects expression in']
# ['has variant part']
# ['variant part of']
# ['related condition']
# ['is sequence variant of', 'is missense variant of', 'is synonymous variant of', 'is nonsense variant of', 'is frameshift variant of', 'is splice site variant of', 'is nearby variant of', 'is non coding variant of']
# ['has sequence variant', 'has missense variant', 'has synonymous variant', 'has nonsense variant', 'has frameshift variant', 'has splice site variant', 'has nearby variant', 'has non coding variant']
# ['is missense variant of']
# ['has missense variant']
# ['is synonymous variant of']
# ['has synonymous variant']
# ['is nonsense variant of']
# ['has nonsense variant']
# ['is frameshift variant of']
# ['has frameshift variant']
# ['is splice site variant of']
# ['has splice site variant']
# ['is nearby variant of']
# ['has nearby variant']
# ['is non coding variant of']
# ['has non coding variant']
# ['disease has basis in']
# ['occurs in disease']
# ['causes adverse event']
# ['adverse event caused by']
# ['contraindicated for']
# ['has contraindication']
# ['has not completed']
# ['not completed by']
# ['has completed']
# ['completed by']
# ['decreases molecular interaction']
# ['molecular interaction decreased by']
# ['increases molecular interaction']
# ['molecular interaction increased by']
# ['in linkage disequilibrium with']
# ['has increased amount']
# ['increased amount of']
# ['has decreased amount']
# ['decreased amount in']
# ['lacks part']
# ['missing from']
# ['develops from']
# ['develops into']
# ['in taxon']
# ['taxon of']
# ['has molecular consequence']
# ['is molecular consequence of']

# %%
def load_predicate_tree_data(biolink_version: str) -> Tuple[List[dict], str]:
    # Grab Biolink yaml file and load into dictionary tree structures
    response = requests.get(f"https://raw.githubusercontent.com/biolink/biolink-model/"
                            f"{biolink_version if biolink_version else 'master'}/biolink-model.yaml",
                            timeout=10)
    if response.status_code == 200:
        # Build predicates tree
        biolink_model = yaml.safe_load(response.text)
        parent_to_child_dict = defaultdict(set)
        for slot_name_english, info in biolink_model["slots"].items():
            slot_name = convert_predicate_to_trapi_format(slot_name_english)
            parent_name_english = info.get("is_a")
            if parent_name_english:
                parent_name = convert_predicate_to_trapi_format(parent_name_english)
                parent_to_child_dict[parent_name].add(slot_name)
        root_node = {"name": "related_to"}
        predicate_tree = get_tree_node_recursive(root_node, parent_to_child_dict)
        pprint(predicate_tree)
        biolink_version = biolink_model["version"]
        return [predicate_tree], biolink_version
    else:
        return [], ""

# %%
def get_tree_node_recursive(root_node: dict, parent_to_child_map: dict):
    root_name = root_node["name"]
    children_predicates = parent_to_child_map.get(root_name, [])
    print(root_node["name"])
    if children_predicates:
        children = []
        for child_predicate in children_predicates:
            child_node = {"name": child_predicate, "parent": root_name}
            child_node = get_tree_node_recursive(child_node, parent_to_child_map)
            children.append(child_node)
        root_node["children"] = sorted(children, key=lambda x: x["name"])
    return root_node

# %%
ptd = load_predicate_tree_data("master")
# pprint(ptd)
# Out:
# related_to
# disease_has_location
# composed_primarily_of
# related_to_at_concept_level
# narrow_match
# close_match
# exact_match
# same_as
# [{'name': 'same_as', 'parent': 'exact_match'}]
# [{'name': 'exact_match', 'parent': 'close_match', 'children': [{'name': 'same_as', 'parent': 'exact_match'}]}]
# superclass_of
# broad_match
# subclass_of
# [{'name': 'narrow_match', 'parent': 'related_to_at_concept_level'}, {'name': 'close_match', 'parent': 'related_to_at_concept_level', 'children': [{'name': 'exact_match', 'parent': 'close_match', 'children': [{'name': 'same_as', 'parent': 'exact_match'}]}]}, {'name': 'superclass_of', 'parent': 'related_to_at_concept_level'}, {'name': 'broad_match', 'parent': 'related_to_at_concept_level'}, {'name': 'subclass_of', 'parent': 'related_to_at_concept_level'}]
# related_to_at_instance_level
# decreased_amount_in
# contraindicated_for
# active_in
# similar_to
# homologous_to
# orthologous_to
# paralogous_to
# xenologous_to
# [{'name': 'orthologous_to', 'parent': 'homologous_to'}, {'name': 'paralogous_to', 'parent': 'homologous_to'}, {'name': 'xenologous_to', 'parent': 'homologous_to'}]
# chemically_similar_to
# [{'name': 'homologous_to', 'parent': 'similar_to', 'children': [{'name': 'orthologous_to', 'parent': 'homologous_to'}, {'name': 'paralogous_to', 'parent': 'homologous_to'}, {'name': 'xenologous_to', 'parent': 'homologous_to'}]}, {'name': 'chemically_similar_to', 'parent': 'similar_to'}]
# has_sequence_location
# caused_by
# in_taxon
# opposite_of
# disease_has_basis_in
# affected_by
# synthesis_affected_by
# synthesis_decreased_by
# synthesis_increased_by
# [{'name': 'synthesis_decreased_by', 'parent': 'synthesis_affected_by'}, {'name': 'synthesis_increased_by', 'parent': 'synthesis_affected_by'}]
# transport_affected_by
# transport_increased_by
# transport_decreased_by
# [{'name': 'transport_increased_by', 'parent': 'transport_affected_by'}, {'name': 'transport_decreased_by', 'parent': 'transport_affected_by'}]
# molecular_modification_affected_by
# molecular_modification_increased_by
# molecular_modification_decreased_by
# [{'name': 'molecular_modification_increased_by', 'parent': 'molecular_modification_affected_by'}, {'name': 'molecular_modification_decreased_by', 'parent': 'molecular_modification_affected_by'}]
# mutation_rate_affected_by
# mutation_rate_decreased_by
# mutation_rate_increased_by
# [{'name': 'mutation_rate_decreased_by', 'parent': 'mutation_rate_affected_by'}, {'name': 'mutation_rate_increased_by', 'parent': 'mutation_rate_affected_by'}]
# expression_affected_by
# expression_decreased_by
# expression_increased_by
# [{'name': 'expression_decreased_by', 'parent': 'expression_affected_by'}, {'name': 'expression_increased_by', 'parent': 'expression_affected_by'}]
# folding_affected_by
# folding_decreased_by
# folding_increased_by
# [{'name': 'folding_decreased_by', 'parent': 'folding_affected_by'}, {'name': 'folding_increased_by', 'parent': 'folding_affected_by'}]
# activity_affected_by
# activity_decreased_by
# activity_increased_by
# [{'name': 'activity_decreased_by', 'parent': 'activity_affected_by'}, {'name': 'activity_increased_by', 'parent': 'activity_affected_by'}]
# response_affected_by
# response_increased_by
# response_decreased_by
# [{'name': 'response_increased_by', 'parent': 'response_affected_by'}, {'name': 'response_decreased_by', 'parent': 'response_affected_by'}]
# process_regulated_by_process
# process_negatively_regulated_by_process
# process_positively_regulated_by_process
# [{'name': 'process_negatively_regulated_by_process', 'parent': 'process_regulated_by_process'}, {'name': 'process_positively_regulated_by_process', 'parent': 'process_regulated_by_process'}]
# secretion_affected_by
# secretion_increased_by
# secretion_decreased_by
# [{'name': 'secretion_increased_by', 'parent': 'secretion_affected_by'}, {'name': 'secretion_decreased_by', 'parent': 'secretion_affected_by'}]
# stability_affected_by
# stability_increased_by
# stability_decreased_by
# [{'name': 'stability_increased_by', 'parent': 'stability_affected_by'}, {'name': 'stability_decreased_by', 'parent': 'stability_affected_by'}]
# entity_regulated_by_entity
# entity_negatively_regulated_by_entity
# entity_positively_regulated_by_entity
# [{'name': 'entity_negatively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}, {'name': 'entity_positively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}]
# localization_affected_by
# localization_increased_by
# localization_decreased_by
# [{'name': 'localization_increased_by', 'parent': 'localization_affected_by'}, {'name': 'localization_decreased_by', 'parent': 'localization_affected_by'}]
# metabolic_processing_affected_by
# metabolic_processing_increased_by
# metabolic_processing_decreased_by
# [{'name': 'metabolic_processing_increased_by', 'parent': 'metabolic_processing_affected_by'}, {'name': 'metabolic_processing_decreased_by', 'parent': 'metabolic_processing_affected_by'}]
# is_ameliorated_by
# splicing_affected_by
# splicing_increased_by
# splicing_decreased_by
# [{'name': 'splicing_increased_by', 'parent': 'splicing_affected_by'}, {'name': 'splicing_decreased_by', 'parent': 'splicing_affected_by'}]
# disrupted_by
# degradation_affected_by
# degradation_increased_by
# degradation_decreased_by
# [{'name': 'degradation_increased_by', 'parent': 'degradation_affected_by'}, {'name': 'degradation_decreased_by', 'parent': 'degradation_affected_by'}]
# uptake_affected_by
# uptake_decreased_by
# uptake_increased_by
# [{'name': 'uptake_decreased_by', 'parent': 'uptake_affected_by'}, {'name': 'uptake_increased_by', 'parent': 'uptake_affected_by'}]
# is_exacerbated_by
# abundance_affected_by
# abundance_increased_by
# abundance_decreased_by
# [{'name': 'abundance_increased_by', 'parent': 'abundance_affected_by'}, {'name': 'abundance_decreased_by', 'parent': 'abundance_affected_by'}]
# [{'name': 'synthesis_affected_by', 'parent': 'affected_by', 'children': [{'name': 'synthesis_decreased_by', 'parent': 'synthesis_affected_by'}, {'name': 'synthesis_increased_by', 'parent': 'synthesis_affected_by'}]}, {'name': 'transport_affected_by', 'parent': 'affected_by', 'children': [{'name': 'transport_decreased_by', 'parent': 'transport_affected_by'}, {'name': 'transport_increased_by', 'parent': 'transport_affected_by'}]}, {'name': 'molecular_modification_affected_by', 'parent': 'affected_by', 'children': [{'name': 'molecular_modification_decreased_by', 'parent': 'molecular_modification_affected_by'}, {'name': 'molecular_modification_increased_by', 'parent': 'molecular_modification_affected_by'}]}, {'name': 'mutation_rate_affected_by', 'parent': 'affected_by', 'children': [{'name': 'mutation_rate_decreased_by', 'parent': 'mutation_rate_affected_by'}, {'name': 'mutation_rate_increased_by', 'parent': 'mutation_rate_affected_by'}]}, {'name': 'expression_affected_by', 'parent': 'affected_by', 'children': [{'name': 'expression_decreased_by', 'parent': 'expression_affected_by'}, {'name': 'expression_increased_by', 'parent': 'expression_affected_by'}]}, {'name': 'folding_affected_by', 'parent': 'affected_by', 'children': [{'name': 'folding_decreased_by', 'parent': 'folding_affected_by'}, {'name': 'folding_increased_by', 'parent': 'folding_affected_by'}]}, {'name': 'activity_affected_by', 'parent': 'affected_by', 'children': [{'name': 'activity_decreased_by', 'parent': 'activity_affected_by'}, {'name': 'activity_increased_by', 'parent': 'activity_affected_by'}]}, {'name': 'response_affected_by', 'parent': 'affected_by', 'children': [{'name': 'response_decreased_by', 'parent': 'response_affected_by'}, {'name': 'response_increased_by', 'parent': 'response_affected_by'}]}, {'name': 'process_regulated_by_process', 'parent': 'affected_by', 'children': [{'name': 'process_negatively_regulated_by_process', 'parent': 'process_regulated_by_process'}, {'name': 'process_positively_regulated_by_process', 'parent': 'process_regulated_by_process'}]}, {'name': 'secretion_affected_by', 'parent': 'affected_by', 'children': [{'name': 'secretion_decreased_by', 'parent': 'secretion_affected_by'}, {'name': 'secretion_increased_by', 'parent': 'secretion_affected_by'}]}, {'name': 'stability_affected_by', 'parent': 'affected_by', 'children': [{'name': 'stability_decreased_by', 'parent': 'stability_affected_by'}, {'name': 'stability_increased_by', 'parent': 'stability_affected_by'}]}, {'name': 'entity_regulated_by_entity', 'parent': 'affected_by', 'children': [{'name': 'entity_negatively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}, {'name': 'entity_positively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}]}, {'name': 'localization_affected_by', 'parent': 'affected_by', 'children': [{'name': 'localization_decreased_by', 'parent': 'localization_affected_by'}, {'name': 'localization_increased_by', 'parent': 'localization_affected_by'}]}, {'name': 'metabolic_processing_affected_by', 'parent': 'affected_by', 'children': [{'name': 'metabolic_processing_decreased_by', 'parent': 'metabolic_processing_affected_by'}, {'name': 'metabolic_processing_increased_by', 'parent': 'metabolic_processing_affected_by'}]}, {'name': 'is_ameliorated_by', 'parent': 'affected_by'}, {'name': 'splicing_affected_by', 'parent': 'affected_by', 'children': [{'name': 'splicing_decreased_by', 'parent': 'splicing_affected_by'}, {'name': 'splicing_increased_by', 'parent': 'splicing_affected_by'}]}, {'name': 'disrupted_by', 'parent': 'affected_by'}, {'name': 'degradation_affected_by', 'parent': 'affected_by', 'children': [{'name': 'degradation_decreased_by', 'parent': 'degradation_affected_by'}, {'name': 'degradation_increased_by', 'parent': 'degradation_affected_by'}]}, {'name': 'uptake_affected_by', 'parent': 'affected_by', 'children': [{'name': 'uptake_decreased_by', 'parent': 'uptake_affected_by'}, {'name': 'uptake_increased_by', 'parent': 'uptake_affecte ...
# has_real_world_evidence_of_association_with
# mentions
# has_phenotype
# has_target
# has_decreased_amount
# transcribed_to
# mentioned_by
# completed_by
# treated_by
# approved_for_treatment_by
# [{'name': 'approved_for_treatment_by', 'parent': 'treated_by'}]
# manifestation_of
# has_contributor
# has_editor
# has_provider
# has_publisher
# has_author
# [{'name': 'has_editor', 'parent': 'has_contributor'}, {'name': 'has_provider', 'parent': 'has_contributor'}, {'name': 'has_publisher', 'parent': 'has_contributor'}, {'name': 'has_author', 'parent': 'has_contributor'}]
# acts_upstream_of
# acts_upstream_of_or_within_negative_effect
# acts_upstream_of_or_within_positive_effect
# acts_upstream_of_negative_effect
# acts_upstream_of_or_within
# acts_upstream_of_positive_effect
# [{'name': 'acts_upstream_of_or_within_negative_effect', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_or_within_positive_effect', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_negative_effect', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_or_within', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_positive_effect', 'parent': 'acts_upstream_of'}]
# not_completed_by
# risk_affected_by
# prevented_by
# [{'name': 'prevented_by', 'parent': 'risk_affected_by'}]
# model_of
# is_molecular_consequence_of
# contains_process
# translates_to
# translation_of
# contribution_from
# produces
# gene_product_of
# taxon_of
# associated_with
# correlated_with
# negatively_correlated_with
# occurs_together_in_literature_with
# positively_correlated_with
# coexpressed_with
# biomarker_for
# has_biomarker
# [{'name': 'negatively_correlated_with', 'parent': 'correlated_with'}, {'name': 'occurs_together_in_literature_with', 'parent': 'correlated_with'}, {'name': 'positively_correlated_with', 'parent': 'correlated_with'}, {'name': 'coexpressed_with', 'parent': 'correlated_with'}, {'name': 'biomarker_for', 'parent': 'correlated_with'}, {'name': 'has_biomarker', 'parent': 'correlated_with'}]
# associated_with_sensitivity_to
# sensitivity_associated_with
# associated_with_resistance_to
# resistance_associated_with
# [{'name': 'correlated_with', 'parent': 'associated_with', 'children': [{'name': 'biomarker_for', 'parent': 'correlated_with'}, {'name': 'coexpressed_with', 'parent': 'correlated_with'}, {'name': 'has_biomarker', 'parent': 'correlated_with'}, {'name': 'negatively_correlated_with', 'parent': 'correlated_with'}, {'name': 'occurs_together_in_literature_with', 'parent': 'correlated_with'}, {'name': 'positively_correlated_with', 'parent': 'correlated_with'}]}, {'name': 'associated_with_sensitivity_to', 'parent': 'associated_with'}, {'name': 'sensitivity_associated_with', 'parent': 'associated_with'}, {'name': 'associated_with_resistance_to', 'parent': 'associated_with'}, {'name': 'resistance_associated_with', 'parent': 'associated_with'}]
# temporally_related_to
# precedes
# preceded_by
# [{'name': 'precedes', 'parent': 'temporally_related_to'}, {'name': 'preceded_by', 'parent': 'temporally_related_to'}]
# phenotype_of
# located_in
# expressed_in
# [{'name': 'expressed_in', 'parent': 'located_in'}]
# increased_amount_of
# has_participant
# actively_involves
# has_capability
# [{'name': 'has_capability', 'parent': 'actively_involves'}]
# has_substrate
# enabled_by
# has_input
# consumes
# [{'name': 'consumes', 'parent': 'has_input'}]
# has_output
# has_catalyst
# [{'name': 'actively_involves', 'parent': 'has_participant', 'children': [{'name': 'has_capability', 'parent': 'actively_involves'}]}, {'name': 'has_substrate', 'parent': 'has_participant'}, {'name': 'enabled_by', 'parent': 'has_participant'}, {'name': 'has_input', 'parent': 'has_participant', 'children': [{'name': 'consumes', 'parent': 'has_input'}]}, {'name': 'has_output', 'parent': 'has_participant'}, {'name': 'has_catalyst', 'parent': 'has_participant'}]
# has_not_completed
# affects_risk_for
# predisposes
# prevents
# [{'name': 'predisposes', 'parent': 'affects_risk_for'}, {'name': 'prevents', 'parent': 'affects_risk_for'}]
# sequence_location_of
# overlaps
# part_of
# is_excipient_of
# is_active_ingredient_of
# variant_part_of
# food_component_of
# nutrient_of
# [{'name': 'nutrient_of', 'parent': 'food_component_of'}]
# plasma_membrane_part_of
# [{'name': 'is_excipient_of', 'parent': 'part_of'}, {'name': 'is_active_ingredient_of', 'parent': 'part_of'}, {'name': 'variant_part_of', 'parent': 'part_of'}, {'name': 'food_component_of', 'parent': 'part_of', 'children': [{'name': 'nutrient_of', 'parent': 'food_component_of'}]}, {'name': 'plasma_membrane_part_of', 'parent': 'part_of'}]
# has_part
# has_plasma_membrane_part
# has_food_component
# has_nutrient
# [{'name': 'has_nutrient', 'parent': 'has_food_component'}]
# has_variant_part
# has_excipient
# has_active_ingredient
# [{'name': 'has_plasma_membrane_part', 'parent': 'has_part'}, {'name': 'has_food_component', 'parent': 'has_part', 'children': [{'name': 'has_nutrient', 'parent': 'has_food_component'}]}, {'name': 'has_variant_part', 'parent': 'has_part'}, {'name': 'has_excipient', 'parent': 'has_part'}, {'name': 'has_active_ingredient', 'parent': 'has_part'}]
# [{'name': 'part_of', 'parent': 'overlaps', 'children': [{'name': 'food_component_of', 'parent': 'part_of', 'children': [{'name': 'nutrient_of', 'parent': 'food_component_of'}]}, {'name': 'is_active_ingredient_of', 'parent': 'part_of'}, {'name': 'is_excipient_of', 'parent': 'part_of'}, {'name': 'plasma_membrane_part_of', 'parent': 'part_of'}, {'name': 'variant_part_of', 'parent': 'part_of'}]}, {'name': 'has_part', 'parent': 'overlaps', 'children': [{'name': 'has_active_ingredient', 'parent': 'has_part'}, {'name': 'has_excipient', 'parent': 'has_part'}, {'name': 'has_food_component', 'parent': 'has_part', 'children': [{'name': 'has_nutrient', 'parent': 'has_food_component'}]}, {'name': 'has_plasma_membrane_part', 'parent': 'has_part'}, {'name': 'has_variant_part', 'parent': 'has_part'}]}]
# increases_amount_or_activity_of
# coexists_with
# in_cell_population_with
# in_complex_with
# colocalizes_with
# in_pathway_with
# [{'name': 'in_cell_population_with', 'parent': 'coexists_with'}, {'name': 'in_complex_with', 'parent': 'coexists_with'}, {'name': 'colocalizes_with', 'parent': 'coexists_with'}, {'name': 'in_pathway_with', 'parent': 'coexists_with'}]
# has_increased_amount
# contributor
# provider
# author
# publisher
# editor
# [{'name': 'provider', 'parent': 'contributor'}, {'name': 'author', 'parent': 'contributor'}, {'name': 'publisher', 'parent': 'contributor'}, {'name': 'editor', 'parent': 'contributor'}]
# develops_into
# has_upstream_actor
# has_upstream_or_within_actor
# has_negative_upstream_or_within_actor
# has_positive_upstream_or_within_actor
# [{'name': 'has_negative_upstream_or_within_actor', 'parent': 'has_upstream_or_within_actor'}, {'name': 'has_positive_upstream_or_within_actor', 'parent': 'has_upstream_or_within_actor'}]
# has_positive_upstream_actor
# has_negative_upstream_actor
# [{'name': 'has_upstream_or_within_actor', 'parent': 'has_upstream_actor', 'children': [{'name': 'has_negative_upstream_or_within_actor', 'parent': 'has_upstream_or_within_actor'}, {'name': 'has_positive_upstream_or_within_actor', 'parent': 'has_upstream_or_within_actor'}]}, {'name': 'has_positive_upstream_actor', 'parent': 'has_upstream_actor'}, {'name': 'has_negative_upstream_actor', 'parent': 'has_upstream_actor'}]
# participates_in
# enables
# is_substrate_of
# catalyzes
# actively_involved_in
# capable_of
# [{'name': 'capable_of', 'parent': 'actively_involved_in'}]
# is_output_of
# is_input_of
# consumed_by
# [{'name': 'consumed_by', 'parent': 'is_input_of'}]
# [{'name': 'enables', 'parent': 'participates_in'}, {'name': 'is_substrate_of', 'parent': 'participates_in'}, {'name': 'catalyzes', 'parent': 'participates_in'}, {'name': 'actively_involved_in', 'parent': 'participates_in', 'children': [{'name': 'capable_of', 'parent': 'actively_involved_in'}]}, {'name': 'is_output_of', 'parent': 'participates_in'}, {'name': 'is_input_of', 'parent': 'participates_in', 'children': [{'name': 'consumed_by', 'parent': 'is_input_of'}]}]
# has_molecular_consequence
# occurs_in
# derives_into
# has_metabolite
# [{'name': 'has_metabolite', 'parent': 'derives_into'}]
# diagnoses
# genetic_association
# gene_associated_with_condition
# condition_associated_with_gene
# [{'name': 'gene_associated_with_condition', 'parent': 'genetic_association'}, {'name': 'condition_associated_with_gene', 'parent': 'genetic_association'}]
# has_completed
# related_condition
# has_gene_product
# occurs_in_disease
# contributes_to
# causes
# causes_adverse_event
# adverse_event_caused_by
# [{'name': 'causes_adverse_event', 'parent': 'causes'}, {'name': 'adverse_event_caused_by', 'parent': 'causes'}]
# [{'name': 'causes', 'parent': 'contributes_to', 'children': [{'name': 'adverse_event_caused_by', 'parent': 'causes'}, {'name': 'causes_adverse_event', 'parent': 'causes'}]}]
# has_manifestation
# in_linkage_disequilibrium_with
# derives_from
# is_metabolite_of
# [{'name': 'is_metabolite_of', 'parent': 'derives_from'}]
# is_sequence_variant_of
# is_synonymous_variant_of
# is_nonsense_variant_of
# is_splice_site_variant_of
# is_non_coding_variant_of
# is_nearby_variant_of
# is_missense_variant_of
# is_frameshift_variant_of
# [{'name': 'is_synonymous_variant_of', 'parent': 'is_sequence_variant_of'}, {'name': 'is_nonsense_variant_of', 'parent': 'is_sequence_variant_of'}, {'name': 'is_splice_site_variant_of', 'parent': 'is_sequence_variant_of'}, {'name': 'is_non_coding_variant_of', 'parent': 'is_sequence_variant_of'}, {'name': 'is_nearby_variant_of', 'parent': 'is_sequence_variant_of'}, {'name': 'is_missense_variant_of', 'parent': 'is_sequence_variant_of'}, {'name': 'is_frameshift_variant_of', 'parent': 'is_sequence_variant_of'}]
# lacks_part
# models
# has_sequence_variant
# has_nonsense_variant
# has_nearby_variant
# has_synonymous_variant
# has_non_coding_variant
# has_frameshift_variant
# has_splice_site_variant
# has_missense_variant
# [{'name': 'has_nonsense_variant', 'parent': 'has_sequence_variant'}, {'name': 'has_nearby_variant', 'parent': 'has_sequence_variant'}, {'name': 'has_synonymous_variant', 'parent': 'has_sequence_variant'}, {'name': 'has_non_coding_variant', 'parent': 'has_sequence_variant'}, {'name': 'has_frameshift_variant', 'parent': 'has_sequence_variant'}, {'name': 'has_splice_site_variant', 'parent': 'has_sequence_variant'}, {'name': 'has_missense_variant', 'parent': 'has_sequence_variant'}]
# interacts_with
# physically_interacts_with
# molecularly_interacts_with
# molecular_interaction_increased_by
# increases_molecular_interaction
# decreases_molecular_interaction
# molecular_interaction_decreased_by
# [{'name': 'molecular_interaction_increased_by', 'parent': 'molecularly_interacts_with'}, {'name': 'increases_molecular_interaction', 'parent': 'molecularly_interacts_with'}, {'name': 'decreases_molecular_interaction', 'parent': 'molecularly_interacts_with'}, {'name': 'molecular_interaction_decreased_by', 'parent': 'molecularly_interacts_with'}]
# chemically_interacts_with
# [{'name': 'molecularly_interacts_with', 'parent': 'physically_interacts_with', 'children': [{'name': 'decreases_molecular_interaction', 'parent': 'molecularly_interacts_with'}, {'name': 'increases_molecular_interaction', 'parent': 'molecularly_interacts_with'}, {'name': 'molecular_interaction_decreased_by', 'parent': 'molecularly_interacts_with'}, {'name': 'molecular_interaction_increased_by', 'parent': 'molecularly_interacts_with'}]}, {'name': 'chemically_interacts_with', 'parent': 'physically_interacts_with'}]
# directly_interacts_with
# genetically_interacts_with
# [{'name': 'physically_interacts_with', 'parent': 'interacts_with', 'children': [{'name': 'chemically_interacts_with', 'parent': 'physically_interacts_with'}, {'name': 'molecularly_interacts_with', 'parent': 'physically_interacts_with', 'children': [{'name': 'decreases_molecular_interaction', 'parent': 'molecularly_interacts_with'}, {'name': 'increases_molecular_interaction', 'parent': 'molecularly_interacts_with'}, {'name': 'molecular_interaction_decreased_by', 'parent': 'molecularly_interacts_with'}, {'name': 'molecular_interaction_increased_by', 'parent': 'molecularly_interacts_with'}]}]}, {'name': 'directly_interacts_with', 'parent': 'interacts_with'}, {'name': 'genetically_interacts_with', 'parent': 'interacts_with'}]
# decreases_amount_or_activity_of
# develops_from
# produced_by
# has_contraindication
# affects
# affects_synthesis_of
# increases_synthesis_of
# decreases_synthesis_of
# [{'name': 'increases_synthesis_of', 'parent': 'affects_synthesis_of'}, {'name': 'decreases_synthesis_of', 'parent': 'affects_synthesis_of'}]
# affects_secretion_of
# increases_secretion_of
# decreases_secretion_of
# [{'name': 'increases_secretion_of', 'parent': 'affects_secretion_of'}, {'name': 'decreases_secretion_of', 'parent': 'affects_secretion_of'}]
# affects_abundance_of
# decreases_abundance_of
# increases_abundance_of
# [{'name': 'decreases_abundance_of', 'parent': 'affects_abundance_of'}, {'name': 'increases_abundance_of', 'parent': 'affects_abundance_of'}]
# affects_folding_of
# increases_folding_of
# decreases_folding_of
# [{'name': 'increases_folding_of', 'parent': 'affects_folding_of'}, {'name': 'decreases_folding_of', 'parent': 'affects_folding_of'}]
# affects_response_to
# increases_response_to
# decreases_response_to
# [{'name': 'increases_response_to', 'parent': 'affects_response_to'}, {'name': 'decreases_response_to', 'parent': 'affects_response_to'}]
# affects_activity_of
# decreases_activity_of
# increases_activity_of
# [{'name': 'decreases_activity_of', 'parent': 'affects_activity_of'}, {'name': 'increases_activity_of', 'parent': 'affects_activity_of'}]
# process_regulates_process
# process_negatively_regulates_process
# process_positively_regulates_process
# [{'name': 'process_negatively_regulates_process', 'parent': 'process_regulates_process'}, {'name': 'process_positively_regulates_process', 'parent': 'process_regulates_process'}]
# entity_regulates_entity
# entity_positively_regulates_entity
# entity_negatively_regulates_entity
# [{'name': 'entity_positively_regulates_entity', 'parent': 'entity_regulates_entity'}, {'name': 'entity_negatively_regulates_entity', 'parent': 'entity_regulates_entity'}]
# exacerbates
# affects_stability_of
# decreases_stability_of
# increases_stability_of
# [{'name': 'decreases_stability_of', 'parent': 'affects_stability_of'}, {'name': 'increases_stability_of', 'parent': 'affects_stability_of'}]
# affects_splicing_of
# increases_splicing_of
# decreases_splicing_of
# [{'name': 'increases_splicing_of', 'parent': 'affects_splicing_of'}, {'name': 'decreases_splicing_of', 'parent': 'affects_splicing_of'}]
# affects_expression_of
# decreases_expression_of
# increases_expression_of
# [{'name': 'decreases_expression_of', 'parent': 'affects_expression_of'}, {'name': 'increases_expression_of', 'parent': 'affects_expression_of'}]
# affects_expression_in
# affects_metabolic_processing_of
# decreases_metabolic_processing_of
# increases_metabolic_processing_of
# [{'name': 'decreases_metabolic_processing_of', 'parent': 'affects_metabolic_processing_of'}, {'name': 'increases_metabolic_processing_of', 'parent': 'affects_metabolic_processing_of'}]
# disrupts
# affects_degradation_of
# increases_degradation_of
# decreases_degradation_of
# [{'name': 'increases_degradation_of', 'parent': 'affects_degradation_of'}, {'name': 'decreases_degradation_of', 'parent': 'affects_degradation_of'}]
# ameliorates
# treats
# approved_to_treat
# [{'name': 'approved_to_treat', 'parent': 'treats'}]
# [{'name': 'treats', 'parent': 'ameliorates', 'children': [{'name': 'approved_to_treat', 'parent': 'treats'}]}]
# affects_transport_of
# decreases_transport_of
# increases_transport_of
# [{'name': 'decreases_transport_of', 'parent': 'affects_transport_of'}, {'name': 'increases_transport_of', 'parent': 'affects_transport_of'}]
# affects_uptake_of
# decreases_uptake_of
# increases_uptake_of
# [{'name': 'decreases_uptake_of', 'parent': 'affects_uptake_of'}, {'name': 'increases_uptake_of', 'parent': 'affects_uptake_of'}]
# affects_mutation_rate_of
# increases_mutation_rate_of
# decreases_mutation_rate_of
# [{'name': 'increases_mutation_rate_of', 'parent': 'affects_mutation_rate_of'}, {'name': 'decreases_mutation_rate_of', 'parent': 'affects_mutation_rate_of'}]
# affects_localization_of
# increases_localization_of
# decreases_localization_of
# [{'name': 'increases_localization_of', 'parent': 'affects_localization_of'}, {'name': 'decreases_localization_of', 'parent': 'affects_localization_of'}]
# affects_molecular_modification_of
# decreases_molecular_modification_of
# increases_molecular_modification_of
# [{'name': 'decreases_molecular_modification_of', 'parent': 'affects_molecular_modification_of'}, {'name': 'increases_molecular_modification_of', 'parent': 'affects_molecular_modification_of'}]
# [{'name': 'affects_synthesis_of', 'parent': 'affects', 'children': [{'name': 'decreases_synthesis_of', 'parent': 'affects_synthesis_of'}, {'name': 'increases_synthesis_of', 'parent': 'affects_synthesis_of'}]}, {'name': 'affects_secretion_of', 'parent': 'affects', 'children': [{'name': 'decreases_secretion_of', 'parent': 'affects_secretion_of'}, {'name': 'increases_secretion_of', 'parent': 'affects_secretion_of'}]}, {'name': 'affects_abundance_of', 'parent': 'affects', 'children': [{'name': 'decreases_abundance_of', 'parent': 'affects_abundance_of'}, {'name': 'increases_abundance_of', 'parent': 'affects_abundance_of'}]}, {'name': 'affects_folding_of', 'parent': 'affects', 'children': [{'name': 'decreases_folding_of', 'parent': 'affects_folding_of'}, {'name': 'increases_folding_of', 'parent': 'affects_folding_of'}]}, {'name': 'affects_response_to', 'parent': 'affects', 'children': [{'name': 'decreases_response_to', 'parent': 'affects_response_to'}, {'name': 'increases_response_to', 'parent': 'affects_response_to'}]}, {'name': 'affects_activity_of', 'parent': 'affects', 'children': [{'name': 'decreases_activity_of', 'parent': 'affects_activity_of'}, {'name': 'increases_activity_of', 'parent': 'affects_activity_of'}]}, {'name': 'process_regulates_process', 'parent': 'affects', 'children': [{'name': 'process_negatively_regulates_process', 'parent': 'process_regulates_process'}, {'name': 'process_positively_regulates_process', 'parent': 'process_regulates_process'}]}, {'name': 'entity_regulates_entity', 'parent': 'affects', 'children': [{'name': 'entity_negatively_regulates_entity', 'parent': 'entity_regulates_entity'}, {'name': 'entity_positively_regulates_entity', 'parent': 'entity_regulates_entity'}]}, {'name': 'exacerbates', 'parent': 'affects'}, {'name': 'affects_stability_of', 'parent': 'affects', 'children': [{'name': 'decreases_stability_of', 'parent': 'affects_stability_of'}, {'name': 'increases_stability_of', 'parent': 'affects_stability_of'}]}, {'name': 'affects_splicing_of', 'parent': 'affects', 'children': [{'name': 'decreases_splicing_of', 'parent': 'affects_splicing_of'}, {'name': 'increases_splicing_of', 'parent': 'affects_splicing_of'}]}, {'name': 'affects_expression_of', 'parent': 'affects', 'children': [{'name': 'decreases_expression_of', 'parent': 'affects_expression_of'}, {'name': 'increases_expression_of', 'parent': 'affects_expression_of'}]}, {'name': 'affects_expression_in', 'parent': 'affects'}, {'name': 'affects_metabolic_processing_of', 'parent': 'affects', 'children': [{'name': 'decreases_metabolic_processing_of', 'parent': 'affects_metabolic_processing_of'}, {'name': 'increases_metabolic_processing_of', 'parent': 'affects_metabolic_processing_of'}]}, {'name': 'disrupts', 'parent': 'affects'}, {'name': 'affects_degradation_of', 'parent': 'affects', 'children': [{'name': 'decreases_degradation_of', 'parent': 'affects_degradation_of'}, {'name': 'increases_degradation_of', 'parent': 'affects_degradation_of'}]}, {'name': 'ameliorates', 'parent': 'affects', 'children': [{'name': 'treats', 'parent': 'ameliorates', 'children': [{'name': 'approved_to_treat', 'parent': 'treats'}]}]}, {'name': 'affects_transport_of', 'parent': 'affects', 'children': [{'name': 'decreases_transport_of', 'parent': 'affects_transport_of'}, {'name': 'increases_transport_of', 'parent': 'affects_transport_of'}]}, {'name': 'affects_uptake_of', 'parent': 'affects', 'children': [{'name': 'decreases_uptake_of', 'parent': 'affects_uptake_of'}, {'name': 'increases_uptake_of', 'parent': 'affects_uptake_of'}]}, {'name': 'affects_mutation_rate_of', 'parent': 'affects', 'children': [{'name': 'decreases_mutation_rate_of', 'parent': 'affects_mutation_rate_of'}, {'name': 'increases_mutation_rate_of', 'parent': 'affects_mutation_rate_of'}]}, {'name': 'affects_localization_of', 'parent': 'affects', 'children': [{'name': 'decreases_localization_of', 'parent': 'affects_localization_of'}, {'name': 'increases_localization_of', 'parent': 'affects_localizatio ...
# location_of
# expresses
# [{'name': 'expresses', 'parent': 'location_of'}]
# target_for
# transcribed_from
# is_diagnosed_by
# missing_from
# [{'name': 'decreased_amount_in', 'parent': 'related_to_at_instance_level'}, {'name': 'contraindicated_for', 'parent': 'related_to_at_instance_level'}, {'name': 'active_in', 'parent': 'related_to_at_instance_level'}, {'name': 'similar_to', 'parent': 'related_to_at_instance_level', 'children': [{'name': 'chemically_similar_to', 'parent': 'similar_to'}, {'name': 'homologous_to', 'parent': 'similar_to', 'children': [{'name': 'orthologous_to', 'parent': 'homologous_to'}, {'name': 'paralogous_to', 'parent': 'homologous_to'}, {'name': 'xenologous_to', 'parent': 'homologous_to'}]}]}, {'name': 'has_sequence_location', 'parent': 'related_to_at_instance_level'}, {'name': 'caused_by', 'parent': 'related_to_at_instance_level'}, {'name': 'in_taxon', 'parent': 'related_to_at_instance_level'}, {'name': 'opposite_of', 'parent': 'related_to_at_instance_level'}, {'name': 'disease_has_basis_in', 'parent': 'related_to_at_instance_level'}, {'name': 'affected_by', 'parent': 'related_to_at_instance_level', 'children': [{'name': 'abundance_affected_by', 'parent': 'affected_by', 'children': [{'name': 'abundance_decreased_by', 'parent': 'abundance_affected_by'}, {'name': 'abundance_increased_by', 'parent': 'abundance_affected_by'}]}, {'name': 'activity_affected_by', 'parent': 'affected_by', 'children': [{'name': 'activity_decreased_by', 'parent': 'activity_affected_by'}, {'name': 'activity_increased_by', 'parent': 'activity_affected_by'}]}, {'name': 'degradation_affected_by', 'parent': 'affected_by', 'children': [{'name': 'degradation_decreased_by', 'parent': 'degradation_affected_by'}, {'name': 'degradation_increased_by', 'parent': 'degradation_affected_by'}]}, {'name': 'disrupted_by', 'parent': 'affected_by'}, {'name': 'entity_regulated_by_entity', 'parent': 'affected_by', 'children': [{'name': 'entity_negatively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}, {'name': 'entity_positively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}]}, {'name': 'expression_affected_by', 'parent': 'affected_by', 'children': [{'name': 'expression_decreased_by', 'parent': 'expression_affected_by'}, {'name': 'expression_increased_by', 'parent': 'expression_affected_by'}]}, {'name': 'folding_affected_by', 'parent': 'affected_by', 'children': [{'name': 'folding_decreased_by', 'parent': 'folding_affected_by'}, {'name': 'folding_increased_by', 'parent': 'folding_affected_by'}]}, {'name': 'is_ameliorated_by', 'parent': 'affected_by'}, {'name': 'is_exacerbated_by', 'parent': 'affected_by'}, {'name': 'localization_affected_by', 'parent': 'affected_by', 'children': [{'name': 'localization_decreased_by', 'parent': 'localization_affected_by'}, {'name': 'localization_increased_by', 'parent': 'localization_affected_by'}]}, {'name': 'metabolic_processing_affected_by', 'parent': 'affected_by', 'children': [{'name': 'metabolic_processing_decreased_by', 'parent': 'metabolic_processing_affected_by'}, {'name': 'metabolic_processing_increased_by', 'parent': 'metabolic_processing_affected_by'}]}, {'name': 'molecular_modification_affected_by', 'parent': 'affected_by', 'children': [{'name': 'molecular_modification_decreased_by', 'parent': 'molecular_modification_affected_by'}, {'name': 'molecular_modification_increased_by', 'parent': 'molecular_modification_affected_by'}]}, {'name': 'mutation_rate_affected_by', 'parent': 'affected_by', 'children': [{'name': 'mutation_rate_decreased_by', 'parent': 'mutation_rate_affected_by'}, {'name': 'mutation_rate_increased_by', 'parent': 'mutation_rate_affected_by'}]}, {'name': 'process_regulated_by_process', 'parent': 'affected_by', 'children': [{'name': 'process_negatively_regulated_by_process', 'parent': 'process_regulated_by_process'}, {'name': 'process_positively_regulated_by_process', 'parent': 'process_regulated_by_process'}]}, {'name': 'response_affected_by', 'parent': 'affected_by', 'children': [{'name': 'response_decreased_by', 'parent': 'response_affected_by'}, {'name': 'response_increased_by', 'parent': 'response_a ...
# [{'name': 'disease_has_location', 'parent': 'related_to'}, {'name': 'composed_primarily_of', 'parent': 'related_to'}, {'name': 'related_to_at_concept_level', 'parent': 'related_to', 'children': [{'name': 'broad_match', 'parent': 'related_to_at_concept_level'}, {'name': 'close_match', 'parent': 'related_to_at_concept_level', 'children': [{'name': 'exact_match', 'parent': 'close_match', 'children': [{'name': 'same_as', 'parent': 'exact_match'}]}]}, {'name': 'narrow_match', 'parent': 'related_to_at_concept_level'}, {'name': 'subclass_of', 'parent': 'related_to_at_concept_level'}, {'name': 'superclass_of', 'parent': 'related_to_at_concept_level'}]}, {'name': 'related_to_at_instance_level', 'parent': 'related_to', 'children': [{'name': 'active_in', 'parent': 'related_to_at_instance_level'}, {'name': 'acts_upstream_of', 'parent': 'related_to_at_instance_level', 'children': [{'name': 'acts_upstream_of_negative_effect', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_or_within', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_or_within_negative_effect', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_or_within_positive_effect', 'parent': 'acts_upstream_of'}, {'name': 'acts_upstream_of_positive_effect', 'parent': 'acts_upstream_of'}]}, {'name': 'affected_by', 'parent': 'related_to_at_instance_level', 'children': [{'name': 'abundance_affected_by', 'parent': 'affected_by', 'children': [{'name': 'abundance_decreased_by', 'parent': 'abundance_affected_by'}, {'name': 'abundance_increased_by', 'parent': 'abundance_affected_by'}]}, {'name': 'activity_affected_by', 'parent': 'affected_by', 'children': [{'name': 'activity_decreased_by', 'parent': 'activity_affected_by'}, {'name': 'activity_increased_by', 'parent': 'activity_affected_by'}]}, {'name': 'degradation_affected_by', 'parent': 'affected_by', 'children': [{'name': 'degradation_decreased_by', 'parent': 'degradation_affected_by'}, {'name': 'degradation_increased_by', 'parent': 'degradation_affected_by'}]}, {'name': 'disrupted_by', 'parent': 'affected_by'}, {'name': 'entity_regulated_by_entity', 'parent': 'affected_by', 'children': [{'name': 'entity_negatively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}, {'name': 'entity_positively_regulated_by_entity', 'parent': 'entity_regulated_by_entity'}]}, {'name': 'expression_affected_by', 'parent': 'affected_by', 'children': [{'name': 'expression_decreased_by', 'parent': 'expression_affected_by'}, {'name': 'expression_increased_by', 'parent': 'expression_affected_by'}]}, {'name': 'folding_affected_by', 'parent': 'affected_by', 'children': [{'name': 'folding_decreased_by', 'parent': 'folding_affected_by'}, {'name': 'folding_increased_by', 'parent': 'folding_affected_by'}]}, {'name': 'is_ameliorated_by', 'parent': 'affected_by'}, {'name': 'is_exacerbated_by', 'parent': 'affected_by'}, {'name': 'localization_affected_by', 'parent': 'affected_by', 'children': [{'name': 'localization_decreased_by', 'parent': 'localization_affected_by'}, {'name': 'localization_increased_by', 'parent': 'localization_affected_by'}]}, {'name': 'metabolic_processing_affected_by', 'parent': 'affected_by', 'children': [{'name': 'metabolic_processing_decreased_by', 'parent': 'metabolic_processing_affected_by'}, {'name': 'metabolic_processing_increased_by', 'parent': 'metabolic_processing_affected_by'}]}, {'name': 'molecular_modification_affected_by', 'parent': 'affected_by', 'children': [{'name': 'molecular_modification_decreased_by', 'parent': 'molecular_modification_affected_by'}, {'name': 'molecular_modification_increased_by', 'parent': 'molecular_modification_affected_by'}]}, {'name': 'mutation_rate_affected_by', 'parent': 'affected_by', 'children': [{'name': 'mutation_rate_decreased_by', 'parent': 'mutation_rate_affected_by'}, {'name': 'mutation_rate_increased_by', 'parent': 'mutation_rate_affected_by'}]}, {'name': 'process_regulated_by_process', 'parent': 'affected_by', 'children': [{'name': 'process_negatively_regulated_by_ ...
# {'children': [{'name': 'composed_primarily_of', 'parent': 'related_to'},
#               {'name': 'disease_has_location', 'parent': 'related_to'},
#               {'children': [{'name': 'broad_match',
#                              'parent': 'related_to_at_concept_level'},
#                             {'children': [{'children': [{'name': 'same_as',
#                                                          'parent': 'exact_match'}],
#                                            'name': 'exact_match',
#                                            'parent': 'close_match'}],
#                              'name': 'close_match',
#                              'parent': 'related_to_at_concept_level'},
#                             {'name': 'narrow_match',
#                              'parent': 'related_to_at_concept_level'},
#                             {'name': 'subclass_of',
#                              'parent': 'related_to_at_concept_level'},
#                             {'name': 'superclass_of',
#                              'parent': 'related_to_at_concept_level'}],
#                'name': 'related_to_at_concept_level',
#                'parent': 'related_to'},
#               {'children': [{'name': 'active_in',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'acts_upstream_of_negative_effect',
#                                            'parent': 'acts_upstream_of'},
#                                           {'name': 'acts_upstream_of_or_within',
#                                            'parent': 'acts_upstream_of'},
#                                           {'name': 'acts_upstream_of_or_within_negative_effect',
#                                            'parent': 'acts_upstream_of'},
#                                           {'name': 'acts_upstream_of_or_within_positive_effect',
#                                            'parent': 'acts_upstream_of'},
#                                           {'name': 'acts_upstream_of_positive_effect',
#                                            'parent': 'acts_upstream_of'}],
#                              'name': 'acts_upstream_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'children': [{'name': 'abundance_decreased_by',
#                                                          'parent': 'abundance_affected_by'},
#                                                         {'name': 'abundance_increased_by',
#                                                          'parent': 'abundance_affected_by'}],
#                                            'name': 'abundance_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'activity_decreased_by',
#                                                          'parent': 'activity_affected_by'},
#                                                         {'name': 'activity_increased_by',
#                                                          'parent': 'activity_affected_by'}],
#                                            'name': 'activity_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'degradation_decreased_by',
#                                                          'parent': 'degradation_affected_by'},
#                                                         {'name': 'degradation_increased_by',
#                                                          'parent': 'degradation_affected_by'}],
#                                            'name': 'degradation_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'name': 'disrupted_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'entity_negatively_regulated_by_entity',
#                                                          'parent': 'entity_regulated_by_entity'},
#                                                         {'name': 'entity_positively_regulated_by_entity',
#                                                          'parent': 'entity_regulated_by_entity'}],
#                                            'name': 'entity_regulated_by_entity',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'expression_decreased_by',
#                                                          'parent': 'expression_affected_by'},
#                                                         {'name': 'expression_increased_by',
#                                                          'parent': 'expression_affected_by'}],
#                                            'name': 'expression_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'folding_decreased_by',
#                                                          'parent': 'folding_affected_by'},
#                                                         {'name': 'folding_increased_by',
#                                                          'parent': 'folding_affected_by'}],
#                                            'name': 'folding_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'name': 'is_ameliorated_by',
#                                            'parent': 'affected_by'},
#                                           {'name': 'is_exacerbated_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'localization_decreased_by',
#                                                          'parent': 'localization_affected_by'},
#                                                         {'name': 'localization_increased_by',
#                                                          'parent': 'localization_affected_by'}],
#                                            'name': 'localization_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'metabolic_processing_decreased_by',
#                                                          'parent': 'metabolic_processing_affected_by'},
#                                                         {'name': 'metabolic_processing_increased_by',
#                                                          'parent': 'metabolic_processing_affected_by'}],
#                                            'name': 'metabolic_processing_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'molecular_modification_decreased_by',
#                                                          'parent': 'molecular_modification_affected_by'},
#                                                         {'name': 'molecular_modification_increased_by',
#                                                          'parent': 'molecular_modification_affected_by'}],
#                                            'name': 'molecular_modification_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'mutation_rate_decreased_by',
#                                                          'parent': 'mutation_rate_affected_by'},
#                                                         {'name': 'mutation_rate_increased_by',
#                                                          'parent': 'mutation_rate_affected_by'}],
#                                            'name': 'mutation_rate_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'process_negatively_regulated_by_process',
#                                                          'parent': 'process_regulated_by_process'},
#                                                         {'name': 'process_positively_regulated_by_process',
#                                                          'parent': 'process_regulated_by_process'}],
#                                            'name': 'process_regulated_by_process',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'response_decreased_by',
#                                                          'parent': 'response_affected_by'},
#                                                         {'name': 'response_increased_by',
#                                                          'parent': 'response_affected_by'}],
#                                            'name': 'response_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'secretion_decreased_by',
#                                                          'parent': 'secretion_affected_by'},
#                                                         {'name': 'secretion_increased_by',
#                                                          'parent': 'secretion_affected_by'}],
#                                            'name': 'secretion_affected_by',
#                                            'parent': 'affected_by'},
#                                           {'children': [{'name': 'splicing_decreased_by',
# ...
#                                           {'name': 'has_substrate',
#                                            'parent': 'has_participant'}],
#                              'name': 'has_participant',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'has_phenotype',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'has_real_world_evidence_of_association_with',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'has_sequence_location',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'has_frameshift_variant',
#                                            'parent': 'has_sequence_variant'},
#                                           {'name': 'has_missense_variant',
#                                            'parent': 'has_sequence_variant'},
#                                           {'name': 'has_nearby_variant',
#                                            'parent': 'has_sequence_variant'},
#                                           {'name': 'has_non_coding_variant',
#                                            'parent': 'has_sequence_variant'},
#                                           {'name': 'has_nonsense_variant',
#                                            'parent': 'has_sequence_variant'},
#                                           {'name': 'has_splice_site_variant',
#                                            'parent': 'has_sequence_variant'},
#                                           {'name': 'has_synonymous_variant',
#                                            'parent': 'has_sequence_variant'}],
#                              'name': 'has_sequence_variant',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'has_target',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'has_negative_upstream_actor',
#                                            'parent': 'has_upstream_actor'},
#                                           {'name': 'has_positive_upstream_actor',
#                                            'parent': 'has_upstream_actor'},
#                                           {'children': [{'name': 'has_negative_upstream_or_within_actor',
#                                                          'parent': 'has_upstream_or_within_actor'},
#                                                         {'name': 'has_positive_upstream_or_within_actor',
#                                                          'parent': 'has_upstream_or_within_actor'}],
#                                            'name': 'has_upstream_or_within_actor',
#                                            'parent': 'has_upstream_actor'}],
#                              'name': 'has_upstream_actor',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'in_linkage_disequilibrium_with',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'in_taxon',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'increased_amount_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'increases_amount_or_activity_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'directly_interacts_with',
#                                            'parent': 'interacts_with'},
#                                           {'name': 'genetically_interacts_with',
#                                            'parent': 'interacts_with'},
#                                           {'children': [{'name': 'chemically_interacts_with',
#                                                          'parent': 'physically_interacts_with'},
#                                                         {'children': [{'name': 'decreases_molecular_interaction',
#                                                                        'parent': 'molecularly_interacts_with'},
#                                                                       {'name': 'increases_molecular_interaction',
#                                                                        'parent': 'molecularly_interacts_with'},
#                                                                       {'name': 'molecular_interaction_decreased_by',
#                                                                        'parent': 'molecularly_interacts_with'},
#                                                                       {'name': 'molecular_interaction_increased_by',
#                                                                        'parent': 'molecularly_interacts_with'}],
#                                                          'name': 'molecularly_interacts_with',
#                                                          'parent': 'physically_interacts_with'}],
#                                            'name': 'physically_interacts_with',
#                                            'parent': 'interacts_with'}],
#                              'name': 'interacts_with',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'is_diagnosed_by',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'is_molecular_consequence_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'is_frameshift_variant_of',
#                                            'parent': 'is_sequence_variant_of'},
#                                           {'name': 'is_missense_variant_of',
#                                            'parent': 'is_sequence_variant_of'},
#                                           {'name': 'is_nearby_variant_of',
#                                            'parent': 'is_sequence_variant_of'},
#                                           {'name': 'is_non_coding_variant_of',
#                                            'parent': 'is_sequence_variant_of'},
#                                           {'name': 'is_nonsense_variant_of',
#                                            'parent': 'is_sequence_variant_of'},
#                                           {'name': 'is_splice_site_variant_of',
#                                            'parent': 'is_sequence_variant_of'},
#                                           {'name': 'is_synonymous_variant_of',
#                                            'parent': 'is_sequence_variant_of'}],
#                              'name': 'is_sequence_variant_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'lacks_part',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'expressed_in',
#                                            'parent': 'located_in'}],
#                              'name': 'located_in',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'expresses',
#                                            'parent': 'location_of'}],
#                              'name': 'location_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'manifestation_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'mentioned_by',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'mentions',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'missing_from',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'model_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'models',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'not_completed_by',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'occurs_in',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'occurs_in_disease',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'opposite_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'children': [{'name': 'has_active_ingredient',
#                                                          'parent': 'has_part'},
#                                                         {'name': 'has_excipient',
#                                                          'parent': 'has_part'},
#                                                         {'children': [{'name': 'has_nutrient',
#                                                                        'parent': 'has_food_component'}],
#                                                          'name': 'has_food_component',
#                                                          'parent': 'has_part'},
#                                                         {'name': 'has_plasma_membrane_part',
#                                                          'parent': 'has_part'},
#                                                         {'name': 'has_variant_part',
#                                                          'parent': 'has_part'}],
#                                            'name': 'has_part',
#                                            'parent': 'overlaps'},
#                                           {'children': [{'children': [{'name': 'nutrient_of',
#                                                                        'parent': 'food_component_of'}],
#                                                          'name': 'food_component_of',
#                                                          'parent': 'part_of'},
#                                                         {'name': 'is_active_ingredient_of',
#                                                          'parent': 'part_of'},
#                                                         {'name': 'is_excipient_of',
#                                                          'parent': 'part_of'},
#                                                         {'name': 'plasma_membrane_part_of',
#                                                          'parent': 'part_of'},
#                                                         {'name': 'variant_part_of',
#                                                          'parent': 'part_of'}],
#                                            'name': 'part_of',
#                                            'parent': 'overlaps'}],
#                              'name': 'overlaps',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'children': [{'name': 'capable_of',
#                                                          'parent': 'actively_involved_in'}],
#                                            'name': 'actively_involved_in',
#                                            'parent': 'participates_in'},
#                                           {'name': 'catalyzes',
#                                            'parent': 'participates_in'},
#                                           {'name': 'enables',
#                                            'parent': 'participates_in'},
#                                           {'children': [{'name': 'consumed_by',
#                                                          'parent': 'is_input_of'}],
#                                            'name': 'is_input_of',
#                                            'parent': 'participates_in'},
#                                           {'name': 'is_output_of',
#                                            'parent': 'participates_in'},
#                                           {'name': 'is_substrate_of',
#                                            'parent': 'participates_in'}],
#                              'name': 'participates_in',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'phenotype_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'produced_by',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'produces',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'related_condition',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'prevented_by',
#                                            'parent': 'risk_affected_by'}],
#                              'name': 'risk_affected_by',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'sequence_location_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'chemically_similar_to',
#                                            'parent': 'similar_to'},
#                                           {'children': [{'name': 'orthologous_to',
#                                                          'parent': 'homologous_to'},
#                                                         {'name': 'paralogous_to',
#                                                          'parent': 'homologous_to'},
#                                                         {'name': 'xenologous_to',
#                                                          'parent': 'homologous_to'}],
#                                            'name': 'homologous_to',
#                                            'parent': 'similar_to'}],
#                              'name': 'similar_to',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'target_for',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'taxon_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'preceded_by',
#                                            'parent': 'temporally_related_to'},
#                                           {'name': 'precedes',
#                                            'parent': 'temporally_related_to'}],
#                              'name': 'temporally_related_to',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'transcribed_from',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'transcribed_to',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'translates_to',
#                              'parent': 'related_to_at_instance_level'},
#                             {'name': 'translation_of',
#                              'parent': 'related_to_at_instance_level'},
#                             {'children': [{'name': 'approved_for_treatment_by',
#                                            'parent': 'treated_by'}],
#                              'name': 'treated_by',
#                              'parent': 'related_to_at_instance_level'}],
#                'name': 'related_to_at_instance_level',
#                'parent': 'related_to'}],
#  'name': 'related_to'}

# %%
def convert_predicate_to_trapi_format(english_predicate: str) -> str:
    # Converts a string like "treated by" to "treated_by"
    return english_predicate.replace(' ', '_')
