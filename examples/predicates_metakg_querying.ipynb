# %%
import csv
import bmt
import requests
import linkml
from linkml_runtime import SchemaView
from collections import defaultdict
from typing import Tuple, List
import requests
import yaml
from pprint import pprint
from biothings_explorer.smartapi_kg.dataload import load_specs
import pandas

tk = bmt.Toolkit('https://raw.githubusercontent.com/biolink/biolink-model/2.2.12/biolink-model.yaml')
tsv_file = open("predicates.tsv", "w")
tsv_attributes = open("attributes.tsv", "w")
tsv_writer = csv.writer(tsv_file, delimiter='\t')
tsv_writer_att = csv.writer(tsv_attributes, delimiter='\t')

# %%
def sample_predicates():
    specs = load_specs()
    kp_titles = []
    for spec in specs:
        if 'x-translator' not in spec['info']:
            continue
        if spec['info']['x-translator']['component'] == 'KP':
            kp_titles.append(spec['info']['title'])
        if 'servers' not in spec:
            continue
        else:
            url = spec['servers'][0]['url']
            apititle = '_'.join(spec['info']['title'].split())
            if url.endswith('/'):
                url = url[:-1]
            predicates_url = f'{url}/meta_knowledge_graph'
            print(predicates_url)
            trapi, predicates = get_predicates(predicates_url)
            # if is_trapi:
            if not predicates:
                continue
            else:
                print("got predicates")
                preds, attribs, url = dump_trapi_predicate_results(predicates, predicates_url)
                predicates = set(preds)
                attributes = set(attribs)
                for pred in predicates:
                    tsv_writer.writerow([apititle, url, pred])
                for attrib in attributes:
                    tsv_writer_att.writerow([apititle, url, attrib])
            # else:
            #     dump_smartapi_predicate_results(spec['info']['title'])

# %%
def in_biolink_model(predicate):
    is_predicate = tk.is_predicate(predicate)
    return is_predicate

# %%
def dump_trapi_predicate_results(predicates, url):
    preds = []
    attribs = []
    for edge in predicates.get('edges'):
        predicate = edge.get('predicate')
        subject = edge.get('subject')
        tobject = edge.get('object')
        if 'attributes' in edge and edge.get('attributes') is not None:
            for attribute in edge.get('attributes'):
                attribs.append(attribute.get('attribute_type_id'))
        preds.append(predicate)
    return preds, attribs, url

            # tsv_writer.writerow([subject, predicate, tobject, url])

# %%
def get_predicates(pr_url):
    try:
        response = requests.get(pr_url)
        if response.status_code == 200:
            return True, response.json()
        else:
            return False, {}
    except:
        return False, {}

# %%
if __name__ == '__main__':
    sample_predicates()
# Out:
# /socio_environmental_exposures_api/v1/meta_knowledge_graph
# /cmaq_exposures_api/v1/meta_knowledge_graph
# /roadway_proximity_api/v1/meta_knowledge_graph
# https://name-resolution-sri.renci.org/meta_knowledge_graph
# https://icees-pcd.renci.org/meta_knowledge_graph
# got predicates
# https://icees-dili-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/proteins/api/meta_knowledge_graph
# https://icees-asthma-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://icees-asthma.renci.org/meta_knowledge_graph
# got predicates
# https://translator-workflow-runner.renci.org/meta_knowledge_graph
# https://icees-pcd-dev.apps.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/ols/api/meta_knowledge_graph
# https://www.ncbi.nlm.nih.gov/research/bionlp/litvar/api/v1/meta_knowledge_graph
# https://icees-dili.renci.org/meta_knowledge_graph
# got predicates
# https://www.ebi.ac.uk/QuickGO/services/meta_knowledge_graph
# https://ontology-kp.apps.renci.org/meta_knowledge_graph
# got predicates
# https://trapi.monarchinitiative.org/1.2/meta_knowledge_graph
# https://medikanren-trapi.ci.transltr.io/v2/meta_knowledge_graph
# https://automat.renci.org/gtex/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/intact/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/gtopdb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/drugcentral/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/chemical-normalization/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/ctd/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/cord19/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/panther/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/textminingkp/1.2/meta_knowledge_graph
# got predicates
# https://bl-lookup-sri.renci.org/meta_knowledge_graph
# https://automat.renci.org/hmdb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/covidkopkg/1.2/meta_knowledge_graph
# got predicates
# https://nodenormalization-sri.renci.org/1.2/meta_knowledge_graph
# https://nodenormalization-dev.apps.renci.org/1.2/meta_knowledge_graph
# https://automat.renci.org/pharos/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/human-goa/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/uberongraph/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/biolink/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/viral-proteome/1.2/meta_knowledge_graph
# got predicates
# https://cam-kp-api.renci.org/1.2.0/meta_knowledge_graph
# got predicates
# https://automat.renci.org/hgnc/1.2/meta_knowledge_graph
# got predicates
# https://cam-kp-api.renci.org/1.2.0/meta_knowledge_graph
# got predicates
# https://automat.renci.org/robokopkg/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/ontological-hierarchy/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/foodb/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/gwas-catalog/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/molepro-fda/1.2/meta_knowledge_graph
# got predicates
# https://automat.renci.org/hetio/1.2/meta_knowledge_graph
# got predicates
# https://explanatory-agent.azurewebsites.net/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/uberon/meta_knowledge_graph
# https://aragorn-dev.apps.renci.org/1.2/meta_knowledge_graph
# http://chp.thayer.dartmouth.edu/meta_knowledge_graph
# got predicates
# https://smart-api.info/api/meta_knowledge_graph
# https://biothings.ncats.io/hpo/meta_knowledge_graph
# https://aragorn.renci.org/1.2/meta_knowledge_graph
# https://cooccurrence-p36smkc6hq-uc.a.run.app/meta_knowledge_graph
# got predicates
# https://spokekp.healthdatascience.cloud/api/v1.2/meta_knowledge_graph
# got predicates
# https://cohd.io/api/meta_knowledge_graph
# got predicates
# https://openpredict.semanticscience.org/meta_knowledge_graph
# got predicates
# https://mygene.info/v3/meta_knowledge_graph
# https://myvariant.info/v1/meta_knowledge_graph
# https://biothings.ncats.io/rhea/meta_knowledge_graph
# https://molepro-trapi.transltr.io/molepro/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://ia.healthdatascience.cloud/api/v1.2/meta_knowledge_graph
# got predicates
# http://mydisease.info/v1/meta_knowledge_graph
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/DISEASES/meta_knowledge_graph
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://translator.broadinstitute.org/genetics_provider/trapi/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/mgigene2phenotype/meta_knowledge_graph
# https://mychem.info/v1/meta_knowledge_graph
# https://biothings.ncats.io/ebigene2phenotype/meta_knowledge_graph
# https://biothings.ncats.io/go_bp/meta_knowledge_graph
# https://arax.ncats.io/beta/api/rtxkg2/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/go_cc/meta_knowledge_graph
# https://arax.ncats.io/api/rtxkg2/v1.2/meta_knowledge_graph
# got predicates
# https://api.bte.ncats.io/v1/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/idisk/meta_knowledge_graph
# https://biothings.ncats.io/go_mf/meta_knowledge_graph
# https://api.bte.ncats.io/v1/team/Service%20Provider/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/multiomics_wellness_kp/meta_knowledge_graph
# https://api.collaboratory.semanticscience.org/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/dgidb/meta_knowledge_graph
# https://biothings.ncats.io/semmeddb/meta_knowledge_graph
# https://biothings.ncats.io/drug_response_kp/meta_knowledge_graph
# https://api.monarchinitiative.org/api/meta_knowledge_graph
# https://biothings.ncats.io/text_mining_targeted_association/meta_knowledge_graph
# https://arax.ncats.io/api/arax/v1.2/meta_knowledge_graph
# got predicates
# https://biothings.ncats.io/clinical_risk_kp/meta_knowledge_graph
# https://arax.ncats.io/beta/api/arax/v1.2/meta_knowledge_graph
# got predicates

# %%
sv = SchemaView('https://raw.githubusercontent.com/biolink/biolink-model/master/biolink-model.yaml')

# %%
for s in sv.all_slots().values():
    if 'related to' in sv.slot_ancestors(s.name):
        print(s.name)
        print(sv.slot_children(s.name))
# Out:
# related to
# ['related to at concept level', 'related to at instance level', 'disease has location', 'composed primarily of']
# related to at concept level
# ['superclass of', 'subclass of', 'close match', 'broad match', 'narrow match']
# related to at instance level
# ['associated with', 'opposite of', 'has real world evidence of association with', 'target for', 'has target', 'active in', 'acts upstream of', 'has upstream actor', 'mentions', 'mentioned by', 'contributor', 'has contributor', 'interacts with', 'affects', 'affected by', 'diagnoses', 'is diagnosed by', 'increases amount or activity of', 'decreases amount or activity of', 'gene product of', 'has gene product', 'transcribed to', 'transcribed from', 'translates to', 'translation of', 'coexists with', 'genetic association', 'affects risk for', 'risk affected by', 'contributes to', 'contribution from', 'caused by', 'treated by', 'has phenotype', 'phenotype of', 'occurs in', 'contains process', 'located in', 'location of', 'similar to', 'has sequence location', 'sequence location of', 'model of', 'models', 'overlaps', 'has participant', 'participates in', 'derives into', 'derives from', 'manifestation of', 'has manifestation', 'produces', 'produced by', 'temporally related to', 'related condition', 'is sequence variant of', 'has sequence variant', 'disease has basis in', 'occurs in disease', 'contraindicated for', 'has contraindication', 'has not completed', 'not completed by', 'has completed', 'completed by', 'in linkage disequilibrium with', 'has increased amount', 'increased amount of', 'has decreased amount', 'decreased amount in', 'lacks part', 'missing from', 'develops from', 'develops into', 'in taxon', 'taxon of', 'has molecular consequence', 'is molecular consequence of']
# associated with
# ['associated with sensitivity to', 'sensitivity associated with', 'associated with resistance to', 'resistance associated with', 'correlated with']
# superclass of
# []
# subclass of
# []
# same as
# []
# close match
# ['exact match']
# exact match
# ['same as']
# broad match
# []
# narrow match
# []
# opposite of
# []
# has real world evidence of association with
# []
# target for
# []
# has target
# []
# active in
# []
# acts upstream of
# ['acts upstream of positive effect', 'acts upstream of negative effect', 'acts upstream of or within', 'acts upstream of or within positive effect', 'acts upstream of or within negative effect']
# has upstream actor
# ['has positive upstream actor', 'has negative upstream actor', 'has upstream or within actor']
# acts upstream of positive effect
# []
# has positive upstream actor
# []
# acts upstream of negative effect
# []
# has negative upstream actor
# []
# acts upstream of or within
# []
# has upstream or within actor
# ['has positive upstream or within actor', 'has negative upstream or within actor']
# acts upstream of or within positive effect
# []
# has positive upstream or within actor
# []
# acts upstream of or within negative effect
# []
# has negative upstream or within actor
# []
# mentions
# []
# mentioned by
# []
# contributor
# ['provider', 'publisher', 'editor', 'author']
# has contributor
# ['has provider', 'has publisher', 'has editor', 'has author']
# provider
# []
# has provider
# []
# publisher
# []
# has publisher
# []
# editor
# []
# has editor
# []
# author
# []
# has author
# []
# interacts with
# ['physically interacts with', 'genetically interacts with', 'directly interacts with']
# physically interacts with
# ['chemically interacts with', 'molecularly interacts with']
# chemically interacts with
# []
# molecularly interacts with
# ['decreases molecular interaction', 'molecular interaction decreased by', 'increases molecular interaction', 'molecular interaction increased by']
# genetically interacts with
# []
# affects
# ['affects abundance of', 'affects activity of', 'affects expression of', 'affects folding of', 'affects localization of', 'affects metabolic processing of', 'affects molecular modification of', 'affects synthesis of', 'affects degradation of', 'affects mutation rate of', 'affects response to', 'affects splicing of', 'affects stability of', 'affects transport of', 'affects secretion of', 'affects uptake of', 'process regulates process', 'entity regulates entity', 'disrupts', 'ameliorates', 'exacerbates', 'affects expression in']
# affected by
# ['abundance affected by', 'activity affected by', 'expression affected by', 'folding affected by', 'localization affected by', 'metabolic processing affected by', 'molecular modification affected by', 'synthesis affected by', 'degradation affected by', 'mutation rate affected by', 'response affected by', 'splicing affected by', 'stability affected by', 'transport affected by', 'secretion affected by', 'uptake affected by', 'process regulated by process', 'entity regulated by entity', 'disrupted by', 'is ameliorated by', 'is exacerbated by']
# associated with sensitivity to
# []
# sensitivity associated with
# []
# associated with resistance to
# []
# resistance associated with
# []
# diagnoses
# []
# is diagnosed by
# []
# increases amount or activity of
# ['increases abundance of', 'increases activity of', 'increases expression of', 'increases folding of', 'increases localization of', 'increases metabolic processing of', 'increases molecular modification of', 'increases synthesis of', 'decreases degradation of', 'increases mutation rate of', 'increases response to', 'increases splicing of', 'increases stability of', 'increases transport of', 'increases secretion of', 'increases uptake of', 'increases molecular interaction']
# decreases amount or activity of
# ['decreases abundance of', 'decreases activity of', 'decreases expression of', 'decreases folding of', 'decreases localization of', 'decreases metabolic processing of', 'decreases molecular modification of', 'decreases synthesis of', 'increases degradation of', 'decreases mutation rate of', 'decreases response to', 'decreases splicing of', 'decreases stability of', 'decreases transport of', 'decreases secretion of', 'decreases uptake of', 'decreases molecular interaction']
# affects abundance of
# ['increases abundance of', 'decreases abundance of']
# abundance affected by
# ['abundance increased by', 'abundance decreased by']
# increases abundance of
# []
# abundance increased by
# []
# decreases abundance of
# []
# abundance decreased by
# []
# increases activity of
# []
# affects activity of
# ['increases activity of', 'decreases activity of']
# activity affected by
# ['activity increased by', 'activity decreased by']
# activity increased by
# []
# decreases activity of
# []
# activity decreased by
# []
# affects expression of
# ['increases expression of', 'decreases expression of']
# expression affected by
# ['expression increased by', 'expression decreased by']
# increases expression of
# []
# expression increased by
# []
# decreases expression of
# []
# expression decreased by
# []
# affects folding of
# ['increases folding of', 'decreases folding of']
# folding affected by
# ['folding increased by', 'folding decreased by']
# increases folding of
# []
# folding increased by
# []
# decreases folding of
# []
# folding decreased by
# []
# affects localization of
# ['increases localization of', 'decreases localization of']
# localization affected by
# ['localization increased by', 'localization decreased by']
# increases localization of
# []
# localization increased by
# []
# decreases localization of
# []
# localization decreased by
# []
# affects metabolic processing of
# ['increases metabolic processing of', 'decreases metabolic processing of']
# metabolic processing affected by
# ['metabolic processing increased by', 'metabolic processing decreased by']
# increases metabolic processing of
# []
# metabolic processing increased by
# []
# decreases metabolic processing of
# []
# metabolic processing decreased by
# []
# affects molecular modification of
# ['increases molecular modification of', 'decreases molecular modification of']
# molecular modification affected by
# ['molecular modification increased by', 'molecular modification decreased by']
# increases molecular modification of
# []
# molecular modification increased by
# []
# decreases molecular modification of
# []
# molecular modification decreased by
# []
# affects synthesis of
# ['increases synthesis of', 'decreases synthesis of']
# synthesis affected by
# ['synthesis increased by', 'synthesis decreased by']
# increases synthesis of
# []
# synthesis increased by
# []
# decreases synthesis of
# []
# synthesis decreased by
# []
# affects degradation of
# ['increases degradation of', 'decreases degradation of']
# degradation affected by
# ['degradation increased by', 'degradation decreased by']
# increases degradation of
# []
# degradation increased by
# []
# decreases degradation of
# []
# degradation decreased by
# []
# affects mutation rate of
# ['increases mutation rate of', 'decreases mutation rate of']
# mutation rate affected by
# ['mutation rate increased by', 'mutation rate decreased by']
# increases mutation rate of
# []
# mutation rate increased by
# []
# decreases mutation rate of
# []
# mutation rate decreased by
# []
# affects response to
# ['increases response to', 'decreases response to']
# response affected by
# ['response increased by', 'response decreased by']
# increases response to
# []
# response increased by
# []
# decreases response to
# []
# response decreased by
# []
# affects splicing of
# ['increases splicing of', 'decreases splicing of']
# splicing affected by
# ['splicing increased by', 'splicing decreased by']
# increases splicing of
# []
# splicing increased by
# []
# decreases splicing of
# []
# splicing decreased by
# []
# affects stability of
# ['increases stability of', 'decreases stability of']
# stability affected by
# ['stability increased by', 'stability decreased by']
# increases stability of
# []
# stability increased by
# []
# decreases stability of
# []
# stability decreased by
# []
# affects transport of
# ['increases transport of', 'decreases transport of']
# transport affected by
# ['transport increased by', 'transport decreased by']
# increases transport of
# []
# transport increased by
# []
# decreases transport of
# []
# transport decreased by
# []
# affects secretion of
# ['increases secretion of', 'decreases secretion of']
# secretion affected by
# ['secretion increased by', 'secretion decreased by']
# increases secretion of
# []
# secretion increased by
# []
# decreases secretion of
# []
# secretion decreased by
# []
# affects uptake of
# ['increases uptake of', 'decreases uptake of']
# uptake affected by
# ['uptake increased by', 'uptake decreased by']
# increases uptake of
# []
# uptake increased by
# []
# decreases uptake of
# []
# uptake decreased by
# []
# process regulates process
# ['process positively regulates process', 'process negatively regulates process']
# process regulated by process
# ['process positively regulated by process', 'process negatively regulated by process']
# process positively regulates process
# []
# process positively regulated by process
# []
# process negatively regulates process
# []
# process negatively regulated by process
# []
# entity regulates entity
# ['entity positively regulates entity', 'entity negatively regulates entity']
# entity regulated by entity
# ['entity positively regulated by entity', 'entity negatively regulated by entity']
# entity positively regulates entity
# []
# entity positively regulated by entity
# []
# entity negatively regulates entity
# []
# entity negatively regulated by entity
# []
# disrupts
# []
# disrupted by
# []
# gene product of
# []
# has gene product
# []
# transcribed to
# []
# transcribed from
# []
# translates to
# []
# translation of
# []
# homologous to
# ['paralogous to', 'orthologous to', 'xenologous to']
# paralogous to
# []
# orthologous to
# []
# xenologous to
# []
# coexists with
# ['in pathway with', 'in complex with', 'in cell population with', 'colocalizes with']
# in pathway with
# []
# in complex with
# []
# in cell population with
# []
# colocalizes with
# []
# genetic association
# ['gene associated with condition', 'condition associated with gene']
# gene associated with condition
# []
# condition associated with gene
# []
# affects risk for
# ['predisposes', 'prevents']
# risk affected by
# ['prevented by']
# predisposes
# []
# contributes to
# ['causes']
# contribution from
# []
# causes
# ['causes adverse event', 'adverse event caused by']
# caused by
# []
# ameliorates
# ['treats']
# is ameliorated by
# []
# exacerbates
# []
# is exacerbated by
# []
# treats
# ['approved to treat']
# treated by
# ['approved for treatment by']
# approved to treat
# []
# approved for treatment by
# []
# prevents
# []
# prevented by
# []
# correlated with
# ['positively correlated with', 'negatively correlated with', 'occurs together in literature with', 'coexpressed with', 'has biomarker', 'biomarker for']
# positively correlated with
# []
# negatively correlated with
# []
# occurs together in literature with
# []
# coexpressed with
# []
# has biomarker
# []
# biomarker for
# []
# expressed in
# []
# expresses
# []
# has phenotype
# []
# phenotype of
# []
# occurs in
# []
# contains process
# []
# located in
# ['expressed in']
# location of
# ['expresses']
# disease has location
# []
# similar to
# ['homologous to', 'chemically similar to']
# chemically similar to
# []
# has sequence location
# []
# sequence location of
# []
# model of
# []
# models
# []
# overlaps
# ['has part', 'part of']
# has part
# ['has plasma membrane part', 'has food component', 'has active ingredient', 'has excipient', 'has variant part']
# has plasma membrane part
# []
# composed primarily of
# []
# plasma membrane part of
# []
# part of
# ['plasma membrane part of', 'food component of', 'is active ingredient of', 'is excipient of', 'variant part of']
# has input
# ['consumes']
# is input of
# ['consumed by']
# has output
# []
# is output of
# []
# has participant
# ['has input', 'has output', 'has catalyst', 'has substrate', 'actively involves', 'enabled by']
# catalyzes
# []
# has catalyst
# []
# has substrate
# []
# is substrate of
# []
# participates in
# ['is input of', 'is output of', 'catalyzes', 'is substrate of', 'actively involved in', 'enables']
# actively involved in
# ['capable of']
# actively involves
# ['has capability']
# capable of
# []
# has capability
# []
# enables
# []
# enabled by
# []
# derives into
# ['has metabolite']
# derives from
# ['is metabolite of']
# is metabolite of
# []
# has metabolite
# []
# food component of
# ['nutrient of']
# has food component
# ['has nutrient']
# nutrient of
# []
# has nutrient
# []
# is active ingredient of
# []
# has active ingredient
# []
# is excipient of
# []
# has excipient
# []
# manifestation of
# []
# has manifestation
# []
# produces
# []
# produced by
# []
# consumes
# []
# consumed by
# []
# temporally related to
# ['precedes', 'preceded by']
# precedes
# []
# preceded by
# []
# directly interacts with
# []
# affects expression in
# []
# has variant part
# []
# variant part of
# []
# related condition
# []
# is sequence variant of
# ['is missense variant of', 'is synonymous variant of', 'is nonsense variant of', 'is frameshift variant of', 'is splice site variant of', 'is nearby variant of', 'is non coding variant of']
# has sequence variant
# ['has missense variant', 'has synonymous variant', 'has nonsense variant', 'has frameshift variant', 'has splice site variant', 'has nearby variant', 'has non coding variant']
# is missense variant of
# []
# has missense variant
# []
# is synonymous variant of
# []
# has synonymous variant
# []
# is nonsense variant of
# []
# has nonsense variant
# []
# is frameshift variant of
# []
# has frameshift variant
# []
# is splice site variant of
# []
# has splice site variant
# []
# is nearby variant of
# []
# has nearby variant
# []
# is non coding variant of
# []
# has non coding variant
# []
# disease has basis in
# []
# occurs in disease
# []
# causes adverse event
# []
# adverse event caused by
# []
# contraindicated for
# []
# has contraindication
# []
# has not completed
# []
# not completed by
# []
# has completed
# []
# completed by
# []
# decreases molecular interaction
# []
# molecular interaction decreased by
# []
# increases molecular interaction
# []
# molecular interaction increased by
# []
# in linkage disequilibrium with
# []
# has increased amount
# []
# increased amount of
# []
# has decreased amount
# []
# decreased amount in
# []
# lacks part
# []
# missing from
# []
# develops from
# []
# develops into
# []
# in taxon
# []
# taxon of
# []
# has molecular consequence
# []
# is molecular consequence of
# []

# %%
def load_predicate_tree_data(biolink_version: str) -> Tuple[List[dict], str]:
    # Grab Biolink yaml file and load into dictionary tree structures
    response = requests.get(f"https://raw.githubusercontent.com/biolink/biolink-model/"
                            f"{biolink_version if biolink_version else 'master'}/biolink-model.yaml",
                            timeout=10)
    if response.status_code == 200:
        # Build predicates tree
        biolink_model = yaml.safe_load(response.text)
        parent_to_child_dict = defaultdict(set)
        for slot_name_english, info in biolink_model["slots"].items():
            slot_name = convert_predicate_to_trapi_format(slot_name_english)
            parent_name_english = info.get("is_a")
            if parent_name_english:
                parent_name = convert_predicate_to_trapi_format(parent_name_english)
                parent_to_child_dict[parent_name].add(slot_name)
        root_node = {"name": "related_to"}
        predicate_tree = get_tree_node_recursive(root_node, parent_to_child_dict)

        biolink_version = biolink_model["version"]
        return [predicate_tree], biolink_version
    else:
        return [], ""

# %%
def get_tree_node_recursive(root_node: dict, parent_to_child_map: dict):
    root_name = root_node["name"]
    children_predicates = parent_to_child_map.get(root_name, [])
    if children_predicates:
        children = []
        for child_predicate in children_predicates:
            child_node = {"name": child_predicate, "parent": root_name}
            child_node = get_tree_node_recursive(child_node, parent_to_child_map)
            children.append(child_node)
        root_node["children"] = sorted(children, key=lambda x: x["name"])
    return root_node

# %%
ptd = load_predicate_tree_data("master")
dataframe = pandas.DataFrame()
for d in ptd[0]:
    record = pandas.json_normalize(d)
    dataframe = dataframe.append(record, ignore_index=True)
# Out:
# /var/folders/2d/1xhwsfs15qb37bv4m62xn0tc0000gp/T/ipykernel_67537/2714310493.py:5: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   dataframe = dataframe.append(record, ignore_index=True)

# %%
def convert_predicate_to_trapi_format(english_predicate: str) -> str:
    # Converts a string like "treated by" to "treated_by"
    return english_predicate.replace(' ', '_')
